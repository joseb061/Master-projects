# %%
import pandas as pd 
import numpy as np
from time import time
import seaborn as sns

# %%
import scikitplot as skplt

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from sklearn import preprocessing

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt
from matplotlib import pyplot

import sys
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Dataset
#
# In this section we import our dataset (already processed and encoded) and check for correlated variables

# %% [markdown]
# The features we are interested in have to be as independent as possible from each other. Therefore, we are going to
# make sure that we don't have any correlated columns with a value higher than .95

# %%
#dataset_original = pd.read_csv(r'..\reports\provisional.csv', index_col = 0)
dataset_original = pd.read_csv(r'Definitive_ML_Data.csv', index_col = 0)
dataset_original = dataset_original.dropna()
dataset = dataset_original.copy()

# %%
dataset
# Out:
#              Away_team  division  matchday result_home     season  \
# 1          Arenas Club         1         1           W  1928-1929
# 2           Real Unión         1         1           W  1928-1929
# 4            Catalunya         1         1           W  1928-1929
# 1             Athletic         1         1           T  1928-1929
# 2               Racing         1         1           W  1928-1929
# ...                ...       ...       ...         ...        ...
# 47993     Ponferradina         2         3           L  2021-2022
# 47997    SD Amorebieta         2         3           L  2021-2022
# 47992  Real Valladolid         2         3           L  2021-2022
# 47992  Real Sociedad B         2         3           T  2021-2022
# 47995        Burgos CF         2         3           W  2021-2022
#
#                   team  GD_home  Pts_difference  home_rank
# 1      Athletic Madrid      0.0             3.0          4
# 2             Espanyol      0.0             3.0          3
# 4          Real Madrid      0.0             3.0          1
# 1             Donostia      0.0            -2.0          5
# 2            Barcelona      0.0             3.0          2
# ...                ...      ...             ...        ...
# 47993           Girona      2.0             0.0         13
# 47997       UD Almería      3.0             5.0          5
# 47992          CD Lugo      0.0            -5.0         17
# 47992   CF Fuenlabrada      1.0             0.0         12
# 47995         SD Eibar     -3.0             1.0         14
#
# [47750 rows x 9 columns]

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

categorical_variables = ["season", "team", "Away_team", "result_home"]

for col in categorical_variables:
    dataset[f"{col}_encoded"] = le.fit_transform(dataset[col])

# %%
dataset = dataset.drop(['result_home','Away_team',"team","season"], axis=1)
dataset
# Out:
#        division  matchday  GD_home  Pts_difference  home_rank  season_encoded  \
# 1             1         1      0.0             3.0          4               0
# 2             1         1      0.0             3.0          3               0
# 4             1         1      0.0             3.0          1               0
# 1             1         1      0.0            -2.0          5               0
# 2             1         1      0.0             3.0          2               0
# ...         ...       ...      ...             ...        ...             ...
# 47993         2         3      2.0             0.0         13              90
# 47997         2         3      3.0             5.0          5              90
# 47992         2         3      0.0            -5.0         17              90
# 47992         2         3      1.0             0.0         12              90
# 47995         2         3     -3.0             1.0         14              90
#
#        team_encoded  Away_team_encoded  result_home_encoded
# 1                12                  7                    2
# 2                68                115                    2
# 4               110                 56                    2
# 1                66                 11                    1
# 2                23                102                    2
# ...             ...                ...                  ...
# 47993            75                 96                    0
# 47997           136                120                    0
# 47992            36                116                    0
# 47992            49                114                    1
# 47995           123                 27                    2
#
# [47750 rows x 9 columns]

# %%
cor_matrix = dataset.corr().abs()
upper_tri = cor_matrix.where(np.triu(np.ones(cor_matrix.shape),k=1).astype(np.bool))

to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.95)]
print(); print(to_drop)
# Out:
# []

# %%
# Compute the correlation matrix
corr = dataset.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=False)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Normal selection of variables and splitting data

# %%
dataset = dataset.dropna()
target = dataset.result_home_encoded
features = ['division','matchday','GD_home','Pts_difference','home_rank','season_encoded','team_encoded','Away_team_encoded']
X = dataset[features]
#X = dataset[['season','division','matchday','team','Away_team','W','GD_cum_before','rank_before']]
X_train,X_test,y_train,y_test = train_test_split(X, target, test_size=0.2, random_state=1, stratify=target)

# %% [markdown]
# ## Function to construct confusion matrix and ROC

# %%
#plot our results
def confusion_matrix(trained_model, y_test, X_test):
    Y_test_pred = trained_model.predict(X_test)

    fig = plt.figure(figsize=(15,6))
    ax1 = fig.add_subplot(121)
    skplt.metrics.plot_confusion_matrix(y_test, Y_test_pred,
                                        title="Confusion Matrix",
                                        cmap="Oranges",
                                        ax=ax1)

    ax2 = fig.add_subplot(122)
    skplt.metrics.plot_confusion_matrix(y_test, Y_test_pred,
                                        normalize=True,
                                        title="Confusion Matrix",
                                        cmap="Purples",
                                        ax=ax2)

def ROC_PRC_matrix(trained_model, y_test, X_test):    
    y_test_probs = trained_model.predict_proba(X_test)
    
    fig = plt.figure(figsize=(15,6))
    ax1 = fig.add_subplot(121)
    skplt.metrics.plot_roc_curve(y_test, y_test_probs,
                       title="Digits ROC Curve", figsize=(12,6), ax=ax1)
    
    ax2 = fig.add_subplot(122)
    skplt.metrics.plot_precision_recall_curve(y_test, y_test_probs,
                        title="Digits Precision-Recall Curve", figsize=(12,6), ax= ax2)

# %% [markdown]
# ## Estimations of parameters in models

# %%
# Looking for best parameter for logistic regression model
for C in [0.001, 0.01, 0.1, 1, 10, 100]:
    logreg = LogisticRegression(C=C).fit(X_train, y_train)
    prediction_in = logreg.predict(X_train)
    accuracy_r2_in = r2_score(y_train, prediction_in)
    prediction_out = logreg.predict(X_test)
    accuracy_r2_out = r2_score(y_test, prediction_out)
    print() 
    print("Logistic Regression with parameter ", C) 
    print("-" * 20)
    print("Accuracy on training set: ",logreg.score(X_train, y_train), "\tR2 training set: ", accuracy_r2_in )
    print("Accuracy on test set: ",logreg.score(X_test, y_test), "\tR2 test set: ", accuracy_r2_out )
# Out:
# Logistic Regression with parameter  0.001
# --------------------
# Accuracy on training set:  0.5173821989528796 	R2 training set:  -0.5137011316875082
# Accuracy on test set:  0.5211518324607329 	R2 test set:  -0.4975591067494789
#
# Logistic Regression with parameter  0.01
# --------------------
# Accuracy on training set:  0.5172774869109947 	R2 training set:  -0.5104645475864729
# Accuracy on test set:  0.5225130890052356 	R2 test set:  -0.48644210154057
#
# Logistic Regression with parameter  0.1
# --------------------
# Accuracy on training set:  0.5159424083769634 	R2 training set:  -0.5190133512446424
# Accuracy on test set:  0.5211518324607329 	R2 test set:  -0.5000920952780912
#
# Logistic Regression with parameter  1
# --------------------
# Accuracy on training set:  0.5175392670157068 	R2 training set:  -0.5128568054002816
# Accuracy on test set:  0.5206282722513089 	R2 test set:  -0.49446323188117525
#
# Logistic Regression with parameter  10
# --------------------
# Accuracy on training set:  0.5180104712041885 	R2 training set:  -0.5205612827712247
# Accuracy on test set:  0.5230366492146596 	R2 test set:  -0.5026250838067032
#
# Logistic Regression with parameter  100
# --------------------
# Accuracy on training set:  0.5206282722513089 	R2 training set:  -0.5222147550837102
# Accuracy on test set:  0.5240837696335079 	R2 test set:  -0.5083946687885421

# %%
# Preprunning for decision tree model, avoiding overfitting
for depth in range(3,8):
    tree = DecisionTreeClassifier(max_depth=depth).fit(X_train, y_train)
    prediction_in = tree.predict(X_train)
    accuracy_r2_in = r2_score(y_train, prediction_in)
    prediction_out = tree.predict(X_test)
    accuracy_r2_out = r2_score(y_test, prediction_out)
    print() 
    print("Decision tree with depth ", depth) 
    print("-" * 20)
    print("Accuracy on training set: ",tree.score(X_train, y_train), "\tR2 training set: ", accuracy_r2_in )
    print("Accuracy on test set: ",tree.score(X_test, y_test), "\tR2 test set: ", accuracy_r2_out )
# Out:
# Decision tree with depth  3
# --------------------
# Accuracy on training set:  0.49856020942408374 	R2 training set:  -0.6803148523668965
# Accuracy on test set:  0.4918324607329843 	R2 test set:  -0.7172255008141226
#
# Decision tree with depth  4
# --------------------
# Accuracy on training set:  0.5208638743455497 	R2 training set:  -0.5606316011525219
# Accuracy on test set:  0.5128795811518324 	R2 test set:  -0.6007080284979631
#
# Decision tree with depth  5
# --------------------
# Accuracy on training set:  0.5343717277486911 	R2 training set:  -0.3537716607819974
# Accuracy on test set:  0.5260732984293194 	R2 test set:  -0.3997576052280649
#
# Decision tree with depth  6
# --------------------
# Accuracy on training set:  0.5397905759162304 	R2 training set:  -0.37572414424988976
# Accuracy on test set:  0.5306806282722513 	R2 test set:  -0.4150962579846609
#
# Decision tree with depth  7
# --------------------
# Accuracy on training set:  0.5524607329842932 	R2 training set:  -0.3925754897324547
# Accuracy on test set:  0.5381151832460733 	R2 test set:  -0.4616751025941399

# %%
# Random forest model

# We set max_depth = 5 as preprunning parameter
# We set max_features as sqrt of n_features to reduce overfitting (pag 102)

for trees in range(5,10):
    for depth in range(2,6):
        random_forest = RandomForestClassifier(max_depth=depth, n_estimators=trees, max_features=3).fit(X_train, y_train)
        prediction_in = random_forest.predict(X_train)
        accuracy_r2_in = r2_score(y_train, prediction_in)
        prediction_out = random_forest.predict(X_test)
        accuracy_r2_out = r2_score(y_test, prediction_out)
        print() 
        print(f"Random_forest with {trees} trees and {depth} depth") 
        print("-" * 40)
        print("Accuracy on training set: ",random_forest.score(X_train, y_train), "\tR2 training set: ", accuracy_r2_in )
        print("Accuracy on test set: ",random_forest.score(X_test, y_test), "\tR2 test set: ", accuracy_r2_out )
# Out:
# Random_forest with 5 trees and 2 depth
# ----------------------------------------
# Accuracy on training set:  0.49282722513089006 	R2 training set:  -0.6954071847510725
# Accuracy on test set:  0.4875392670157068 	R2 test set:  -0.7238394153054988
#
# Random_forest with 5 trees and 3 depth
# ----------------------------------------
# Accuracy on training set:  0.5139267015706807 	R2 training set:  -0.6119596033635073
# Accuracy on test set:  0.506282722513089 	R2 test set:  -0.656011611372662
#
# Random_forest with 5 trees and 4 depth
# ----------------------------------------
# Accuracy on training set:  0.5265183246073298 	R2 training set:  -0.5470168397709925
# Accuracy on test set:  0.5186387434554974 	R2 test set:  -0.5798812339293742
#
# Random_forest with 5 trees and 5 depth
# ----------------------------------------
# Accuracy on training set:  0.535130890052356 	R2 training set:  -0.48467741556409294
# Accuracy on test set:  0.5334031413612565 	R2 test set:  -0.5022029190519346
#
# Random_forest with 6 trees and 2 depth
# ----------------------------------------
# Accuracy on training set:  0.49863874345549736 	R2 training set:  -0.6641671121236872
# Accuracy on test set:  0.493717277486911 	R2 test set:  -0.6906291212636948
#
# Random_forest with 6 trees and 3 depth
# ----------------------------------------
# Accuracy on training set:  0.5039005235602094 	R2 training set:  -0.6390484050786951
# Accuracy on test set:  0.4981151832460733 	R2 test set:  -0.6686765540157227
#
# Random_forest with 6 trees and 4 depth
# ----------------------------------------
# Accuracy on training set:  0.5328795811518324 	R2 training set:  -0.49582955860787803
# Accuracy on test set:  0.5240837696335079 	R2 test set:  -0.5396348606414254
#
# Random_forest with 6 trees and 5 depth
# ----------------------------------------
# Accuracy on training set:  0.5379581151832461 	R2 training set:  -0.4671576451041404
# Accuracy on test set:  0.5315183246073298 	R2 test set:  -0.501780754297166
#
# Random_forest with 7 trees and 2 depth
# ----------------------------------------
# Accuracy on training set:  0.48837696335078534 	R2 training set:  -0.7241846390407134
# Accuracy on test set:  0.4863874345549738 	R2 test set:  -0.7350971420993306
#
# Random_forest with 7 trees and 3 depth
# ----------------------------------------
# Accuracy on training set:  0.5092670157068063 	R2 training set:  -0.6337361855215609
# Accuracy on test set:  0.5009424083769634 	R2 test set:  -0.6741646958277159
#
# Random_forest with 7 trees and 4 depth
# ----------------------------------------
# Accuracy on training set:  0.5146073298429319 	R2 training set:  -0.5940528500219091
# Accuracy on test set:  0.5079581151832461 	R2 test set:  -0.62969667499208
#
# Random_forest with 7 trees and 5 depth
# ----------------------------------------
# Accuracy on training set:  0.5272774869109947 	R2 training set:  -0.5456799898162168
# Accuracy on test set:  0.5192670157068063 	R2 test set:  -0.5874801995152108
#
# Random_forest with 8 trees and 2 depth
# ----------------------------------------
# Accuracy on training set:  0.4967277486910995 	R2 training set:  -0.6719067697565979
# Accuracy on test set:  0.49099476439790574 	R2 test set:  -0.7023090128122953
#
# Random_forest with 8 trees and 3 depth
# ----------------------------------------
# Accuracy on training set:  0.5051047120418848 	R2 training set:  -0.6290923909418142
# Accuracy on test set:  0.49989528795811516 	R2 test set:  -0.6523528501646667
#
# Random_forest with 8 trees and 4 depth
# ----------------------------------------
# Accuracy on training set:  0.5233769633507853 	R2 training set:  -0.5582041630767451
# Accuracy on test set:  0.5161256544502618 	R2 test set:  -0.5917018470628976
#
# Random_forest with 8 trees and 5 depth
# ----------------------------------------
# Accuracy on training set:  0.5365706806282723 	R2 training set:  -0.463428537335556
# Accuracy on test set:  0.5308900523560209 	R2 test set:  -0.5026250838067032
#
# Random_forest with 9 trees and 2 depth
# ----------------------------------------
# Accuracy on training set:  0.4939528795811518 	R2 training set:  -0.6893561796926151
# Accuracy on test set:  0.48963350785340315 	R2 test set:  -0.7125816885116669
#
# Random_forest with 9 trees and 3 depth
# ----------------------------------------
# Accuracy on training set:  0.5058638743455497 	R2 training set:  -0.6545629006064844
# Accuracy on test set:  0.4991623036649215 	R2 test set:  -0.691754893943078
#
# Random_forest with 9 trees and 4 depth
# ----------------------------------------
# Accuracy on training set:  0.5268586387434555 	R2 training set:  -0.540015967639405
# Accuracy on test set:  0.5225130890052356 	R2 test set:  -0.5674977344561591
#
# Random_forest with 9 trees and 5 depth
# ----------------------------------------
# Accuracy on training set:  0.543455497382199 	R2 training set:  -0.44879354835696117
# Accuracy on test set:  0.5359162303664922 	R2 test set:  -0.4878493173897991

# %% [markdown]
# As we can see, the best results are obtained for the following metrics:
# - Random Forest with 7 trees and 5 depth
# - Logistic Regression with the parameter 0.01
# - Decision Tree with deph 7
#
# Now we will decide which one to choose.

# %%
names = ["Logistic Regression", "Decision Tree", "Random Forest"]
from sklearn.multiclass import OneVsRestClassifier
from sklearn.multiclass import OneVsOneClassifier

classifiers = [
    #KNeighborsClassifier(3),
    LogisticRegression(solver='sag', multi_class='auto', max_iter=1000, C=100),
    DecisionTreeClassifier(max_depth=7),
    RandomForestClassifier(max_depth=5, n_estimators=5, max_features=3),
]

for name, clf in zip(names, classifiers):
        #model = OneVsOneClassifier(clf).fit(X_train, y_train)
        model = clf.fit(X_train, y_train)
        prediction_in = model.predict(X_train)
        accuracy_r2_in = r2_score(y_train, prediction_in)
        prediction_out = model.predict(X_test)
        accuracy_r2_out = r2_score(y_test, prediction_out)
        print() 
        print(name) 
        print("-" * 20)
        print("Accuracy on training set: ",model.score(X_train, y_train))
        print("Accuracy on test set: ",model.score(X_test, y_test))
        ROC_PRC_matrix(model, y_test, X_test)
        confusion_matrix(model, y_test, X_test)
# Out:
# Logistic Regression
# --------------------
# Accuracy on training set:  0.5175130890052356
# Accuracy on test set:  0.5201047120418848
#
# Decision Tree
# --------------------
# Accuracy on training set:  0.5524607329842932
# Accuracy on test set:  0.5381151832460733
#
# Random Forest
# --------------------
# Accuracy on training set:  0.5357329842931937
# Accuracy on test set:  0.5298429319371728

# %% [markdown]
# ## Selected Best Model:
# - Desition tree model with depth 7 , acc = 0.5381151832460733

# %% [markdown]
# ## Model analysis, features importance

# %%
tree = DecisionTreeClassifier(max_depth=7).fit(X_train, y_train)
prediction_in = tree.predict(X_train)
accuracy_r2_in = r2_score(y_train, prediction_in)
prediction_out = tree.predict(X_test)
accuracy_r2_out = r2_score(y_test, prediction_out)

importances = pd.Series(tree.feature_importances_, index=features)
importances.sort_values(ascending=True).plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
dataset_original
# Out:
#              Away_team  division  matchday result_home     season  \
# 1          Arenas Club         1         1           W  1928-1929
# 2           Real Unión         1         1           W  1928-1929
# 4            Catalunya         1         1           W  1928-1929
# 1             Athletic         1         1           T  1928-1929
# 2               Racing         1         1           W  1928-1929
# ...                ...       ...       ...         ...        ...
# 47993     Ponferradina         2         3           L  2021-2022
# 47997    SD Amorebieta         2         3           L  2021-2022
# 47992  Real Valladolid         2         3           L  2021-2022
# 47992  Real Sociedad B         2         3           T  2021-2022
# 47995        Burgos CF         2         3           W  2021-2022
#
#                   team  GD_home  Pts_difference  home_rank
# 1      Athletic Madrid      0.0             3.0          4
# 2             Espanyol      0.0             3.0          3
# 4          Real Madrid      0.0             3.0          1
# 1             Donostia      0.0            -2.0          5
# 2            Barcelona      0.0             3.0          2
# ...                ...      ...             ...        ...
# 47993           Girona      2.0             0.0         13
# 47997       UD Almería      3.0             5.0          5
# 47992          CD Lugo      0.0            -5.0         17
# 47992   CF Fuenlabrada      1.0             0.0         12
# 47995         SD Eibar     -3.0             1.0         14
#
# [47750 rows x 9 columns]

# %% [markdown]
# ## De encoding

# %%
result_in = le.inverse_transform(prediction_in).tolist()
result_out = le.inverse_transform(prediction_out).tolist()
result = result_in + result_out

# %%
dataset_original['Predictions'] = result

# %%
dataset_original.to_csv(r'../reports/Results.csv')
