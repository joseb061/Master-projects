# %%
import pandas as pd 
import numpy as np
from time import time
import seaborn as sns

# %%
import scikitplot as skplt

from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, mean_squared_error
from sklearn import preprocessing

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt
from matplotlib import pyplot

import sys
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Dataset
#
# In this section we import the dataset that we have constructed and we encoded the variables. Then, we check for correlated variables.

# %% [markdown]
# The features we are interested in have to be as independent as possible from each other. Therefore, we are going to
# make sure that we don't have any correlated columns with a value higher than .95

# %%
dataset_original = pd.read_csv(r'Definitive_ML_Data.csv', index_col = 0)
dataset_original = dataset_original.dropna()
dataset = dataset_original.copy()

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

categorical_variables = ["season", "team", "Away_team", "result_home"]

for col in categorical_variables:
    dataset[f"{col}_encoded"] = le.fit_transform(dataset[col])
    
dataset = dataset.drop(categorical_variables, axis=1)

# %%
# Cheking for features too correlated
cor_matrix = dataset.corr().abs()
upper_tri = cor_matrix.where(np.triu(np.ones(cor_matrix.shape),k=1).astype(np.bool))

to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.95)]
print(); print(to_drop)
# Out:
# []

# %%
# Compute the correlation matrix
corr = dataset.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=False)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Splitting data

# %%
target = dataset.result_home_encoded
X = dataset.loc[:, dataset.columns != 'result_home_encoded']
X_train,X_test,y_train,y_test = train_test_split(X, target, test_size=0.2, random_state=1, stratify=target)

# %% [markdown]
# ## Function to construct Confusion matrix and ROC

# %%
#plot our results
def confusion_matrix(trained_model, y_test, X_test):
    Y_test_pred = trained_model.predict(X_test)

    fig = plt.figure(figsize=(15,6))
    ax1 = fig.add_subplot(121)
    skplt.metrics.plot_confusion_matrix(y_test, Y_test_pred,
                                        title="Confusion Matrix",
                                        cmap="Oranges",
                                        ax=ax1)

    ax2 = fig.add_subplot(122)
    skplt.metrics.plot_confusion_matrix(y_test, Y_test_pred,
                                        normalize=True,
                                        title="Confusion Matrix",
                                        cmap="Purples",
                                        ax=ax2)

def ROC_PRC_matrix(trained_model, y_test, X_test):    
    y_test_probs = trained_model.predict_proba(X_test)
    
    fig = plt.figure(figsize=(15,6))
    ax1 = fig.add_subplot(121)
    skplt.metrics.plot_roc_curve(y_test, y_test_probs,
                       title="Digits ROC Curve", figsize=(12,6), ax=ax1)
    
    ax2 = fig.add_subplot(122)
    skplt.metrics.plot_precision_recall_curve(y_test, y_test_probs,
                        title="Digits Precision-Recall Curve", figsize=(12,6), ax= ax2)

# %% [markdown]
# ## Estimations of parameters in models

# %% [markdown]
# We have decided to use the next models: **Logistic Regression**, **Decision Tree** and **Random Forest**. In order to obtain better performance we decided to do a search for the parameters that produce better performance on each model.

# %% [markdown]
# ### Logistic Regression Analysis
# For the **Logistic Regression** we can set different values for the parameter *C*, this one correspond to a L2 regularization parameter, the higher is the more regularization is applied.
# A useful point of view of the parameter is that when takes a high value it tries to fit the training data as much as possible and for low values the models puts more emphasis to adjust the "majority" of the data points.

# %%
# Looking for best parameter for logistic regression model
C_values = [0.001, 0.01, 0.1, 1, 10, 100, 1000]
Accuracy_training_logreg = [] * len(C_values)
Accuracy_test_logreg = [] * len(C_values)
for C in C_values:
    logreg = LogisticRegression(C=C).fit(X_train, y_train)
    prediction_in = logreg.predict(X_train)
    accuracy_f1_in = f1_score(y_train, prediction_in, average="weighted")
    prediction_out = logreg.predict(X_test)
    accuracy_f1_out = f1_score(y_test, prediction_out, average="weighted")
    print() 
    print("Logistic Regression with parameter ", C) 
    print("-" * 30)
    print("Accuracy on training set: ",logreg.score(X_train, y_train), "\tf1 training set: ", accuracy_f1_in )
    print("Accuracy on test set: ",logreg.score(X_test, y_test), "\tf1 test set: ", accuracy_f1_out )
    Accuracy_training_logreg.append(logreg.score(X_train, y_train))
    Accuracy_test_logreg.append(logreg.score(X_test, y_test))
# Out:
# Logistic Regression with parameter  0.001
# ------------------------------
# Accuracy on training set:  0.5173821989528796 	f1 training set:  0.4887653469692314
# Accuracy on test set:  0.5211518324607329 	f1 test set:  0.4915077443623607
#
# Logistic Regression with parameter  0.01
# ------------------------------
# Accuracy on training set:  0.5172774869109947 	f1 training set:  0.48891580945512214
# Accuracy on test set:  0.5225130890052356 	f1 test set:  0.4936465531338285
#
# Logistic Regression with parameter  0.1
# ------------------------------
# Accuracy on training set:  0.5159424083769634 	f1 training set:  0.4877339720739352
# Accuracy on test set:  0.5211518324607329 	f1 test set:  0.4921300675600489
#
# Logistic Regression with parameter  1
# ------------------------------
# Accuracy on training set:  0.5175392670157068 	f1 training set:  0.48891046667745064
# Accuracy on test set:  0.5206282722513089 	f1 test set:  0.4909713126044269
#
# Logistic Regression with parameter  10
# ------------------------------
# Accuracy on training set:  0.5180104712041885 	f1 training set:  0.4884339755237997
# Accuracy on test set:  0.5230366492146596 	f1 test set:  0.49268574693575873
#
# Logistic Regression with parameter  100
# ------------------------------
# Accuracy on training set:  0.5206282722513089 	f1 training set:  0.4881616497660324
# Accuracy on test set:  0.5240837696335079 	f1 test set:  0.49139989556909053
#
# Logistic Regression with parameter  1000
# ------------------------------
# Accuracy on training set:  0.5182984293193718 	f1 training set:  0.48710684695281176
# Accuracy on test set:  0.5232460732984293 	f1 test set:  0.4914633459652647

# %%
# We plot the results
fig,ax = plt.subplots()
ax.plot(C_values, Accuracy_training_logreg, color="red")
ax.set_xlabel("C values",fontsize=14)
ax.set_ylabel("Accuracy on training set",color="red",fontsize=14)
ax2=ax.twinx()
ax2.plot(C_values, Accuracy_test_logreg,color="blue")
ax2.set_ylabel("Accuracy on test set",color="blue",fontsize=14)
plt.show()

# %% [markdown]
# As show in the graph and in the results, we obtain an accuracy on test set of ~ 0.52 with C = 100, so we will take this parameter as reference for logistic regression.

# %% [markdown]
# ### Decision Trees Analysis
# For **Decision Trees** model we have to control the complexity of the model, for that purpose we will do a *pre-prunning* determining the a maximum depth where the model will stop the creation of the tree.

# %%
# Preprunning for decision tree model, avoiding overfitting
depths = range(3,15)
Accuracy_training_tree = [] * len(depths)
Accuracy_test_tree = [] * len(depths)
for depth in depths:
    tree = DecisionTreeClassifier(max_depth=depth).fit(X_train, y_train)
    prediction_in = tree.predict(X_train)
    accuracy_f1_in = f1_score(y_train, prediction_in, average="weighted")
    prediction_out = tree.predict(X_test)
    accuracy_f1_out = f1_score(y_test, prediction_out, average="weighted")
    print() 
    print("Decision tree with depth ", depth) 
    print("-" * 30)
    print("Accuracy on training set: ",tree.score(X_train, y_train), "\tf1 training set: ", accuracy_f1_in )
    print("Accuracy on test set: ",tree.score(X_test, y_test), "\tf1 test set: ", accuracy_f1_out )
    Accuracy_training_tree.append(tree.score(X_train, y_train))
    Accuracy_test_tree.append(tree.score(X_test, y_test))
# Out:
# Decision tree with depth  3
# ------------------------------
# Accuracy on training set:  0.49856020942408374 	f1 training set:  0.43092413748837455
# Accuracy on test set:  0.4918324607329843 	f1 test set:  0.42533642891605755
#
# Decision tree with depth  4
# ------------------------------
# Accuracy on training set:  0.5208638743455497 	f1 training set:  0.48503329697133185
# Accuracy on test set:  0.5128795811518324 	f1 test set:  0.478604449126395
#
# Decision tree with depth  5
# ------------------------------
# Accuracy on training set:  0.5343717277486911 	f1 training set:  0.5287421229664375
# Accuracy on test set:  0.5260732984293194 	f1 test set:  0.5202462282468803
#
# Decision tree with depth  6
# ------------------------------
# Accuracy on training set:  0.5397905759162304 	f1 training set:  0.5233333899454297
# Accuracy on test set:  0.5306806282722513 	f1 test set:  0.5153676637641463
#
# Decision tree with depth  7
# ------------------------------
# Accuracy on training set:  0.5524607329842932 	f1 training set:  0.5248730335007484
# Accuracy on test set:  0.5381151832460733 	f1 test set:  0.5131393184574335
#
# Decision tree with depth  8
# ------------------------------
# Accuracy on training set:  0.5620680628272251 	f1 training set:  0.5448892102376358
# Accuracy on test set:  0.538848167539267 	f1 test set:  0.5227939770385598
#
# Decision tree with depth  9
# ------------------------------
# Accuracy on training set:  0.5770942408376963 	f1 training set:  0.5644052119961899
# Accuracy on test set:  0.5443979057591622 	f1 test set:  0.5331813937219921
#
# Decision tree with depth  10
# ------------------------------
# Accuracy on training set:  0.595890052356021 	f1 training set:  0.583525752980195
# Accuracy on test set:  0.5415706806282723 	f1 test set:  0.530169654494397
#
# Decision tree with depth  11
# ------------------------------
# Accuracy on training set:  0.6167015706806283 	f1 training set:  0.6063364553676855
# Accuracy on test set:  0.5427225130890052 	f1 test set:  0.5325947575141227
#
# Decision tree with depth  12
# ------------------------------
# Accuracy on training set:  0.643586387434555 	f1 training set:  0.6351551485305887
# Accuracy on test set:  0.5362303664921466 	f1 test set:  0.5263921166422302
#
# Decision tree with depth  13
# ------------------------------
# Accuracy on training set:  0.6749476439790576 	f1 training set:  0.6694205772017421
# Accuracy on test set:  0.5270157068062827 	f1 test set:  0.5203580572140662
#
# Decision tree with depth  14
# ------------------------------
# Accuracy on training set:  0.7136387434554974 	f1 training set:  0.7098159901264997
# Accuracy on test set:  0.518848167539267 	f1 test set:  0.5138335549876837

# %%
# We plot the results
fig,ax = plt.subplots()
ax.plot(depths, Accuracy_training_tree, color="red")
ax.set_xlabel("depths",fontsize=14)
ax.set_ylabel("Accuracy on training set",color="red",fontsize=14)
ax2=ax.twinx()
ax2.plot(depths, Accuracy_test_tree,color="blue")
ax2.set_ylabel("Accuracy on test set",color="blue",fontsize=14)
plt.show()

# %% [markdown]
# As shown in the previous plot, is essential controlling the complexity of the model to avoid overfitting. In fact, for high values of depth is a clearly overfitting on the model.
# Then, we will take depth = 11 as parameter of reference for decision trees, where we are obtaining an accuracy on test set of ~ 0.54.

# %% [markdown]
# ### Random Forest Analysis

# %% [markdown]
# For **Random Forests** we will set values of 2 parameters: number of trees and depth. Also, in order to avoid overfitting we decided to set *max_features* as the square of the number of features of our model.

# %%
# Random forest model
import numpy as np

n_trees = range(3,15)
Accuracy_training_forest = np.zeros((len(n_trees), len(depths)))
Accuracy_test_forest = np.zeros((len(n_trees), len(depths)))
j = 0

for trees in n_trees:
    i = 0
    for depth in depths:
        random_forest = RandomForestClassifier(max_depth=depth, n_estimators=trees, max_features=3).fit(X_train, y_train)
        prediction_in = random_forest.predict(X_train)
        accuracy_f1_in = f1_score(y_train, prediction_in, average='weighted')
        prediction_out = random_forest.predict(X_test)
        accuracy_f1_out = f1_score(y_test, prediction_out, average='weighted')
        print() 
        print(f"Random_forest with {trees} trees and {depth} depth") 
        print("-" * 40)
        print("Accuracy on training set: ",random_forest.score(X_train, y_train), "\tf1 training set: ", accuracy_f1_in )
        print("Accuracy on test set: ",random_forest.score(X_test, y_test), "\tf1 test set: ", accuracy_f1_out )
        Accuracy_training_forest[i][j] = random_forest.score(X_train, y_train)
        Accuracy_test_forest[i][j] = random_forest.score(X_test, y_test)
        i = i + 1
    j = j + 1
# Out:
# Random_forest with 3 trees and 3 depth
# ----------------------------------------
# Accuracy on training set:  0.5039790575916231 	f1 training set:  0.44557319692631325
# Accuracy on test set:  0.4961256544502618 	f1 test set:  0.4380860591292016
#
# Random_forest with 3 trees and 4 depth
# ----------------------------------------
# Accuracy on training set:  0.513455497382199 	f1 training set:  0.4752982070276203
# Accuracy on test set:  0.5067015706806283 	f1 test set:  0.4708716094139343
#
# Random_forest with 3 trees and 5 depth
# ----------------------------------------
# Accuracy on training set:  0.5163089005235602 	f1 training set:  0.4706057260943896
# Accuracy on test set:  0.5124607329842932 	f1 test set:  0.4667137472730052
#
# Random_forest with 3 trees and 6 depth
# ----------------------------------------
# Accuracy on training set:  0.5431937172774869 	f1 training set:  0.5243050838260999
# Accuracy on test set:  0.5347643979057591 	f1 test set:  0.5162444263653184
#
# Random_forest with 3 trees and 7 depth
# ----------------------------------------
# Accuracy on training set:  0.5528534031413612 	f1 training set:  0.5333509690941666
# Accuracy on test set:  0.5421989528795812 	f1 test set:  0.5231060962423975
#
# Random_forest with 3 trees and 8 depth
# ----------------------------------------
# Accuracy on training set:  0.5647905759162304 	f1 training set:  0.5473225805612981
# Accuracy on test set:  0.5408376963350785 	f1 test set:  0.5241873897446032
#
# Random_forest with 3 trees and 9 depth
# ----------------------------------------
# Accuracy on training set:  0.5809685863874345 	f1 training set:  0.5651364442337257
# Accuracy on test set:  0.5426178010471204 	f1 test set:  0.5259834960372519
#
# Random_forest with 3 trees and 10 depth
# ----------------------------------------
# Accuracy on training set:  0.6082460732984293 	f1 training set:  0.5950856124356521
# Accuracy on test set:  0.5510994764397906 	f1 test set:  0.5387507930522164
#
# Random_forest with 3 trees and 11 depth
# ----------------------------------------
# Accuracy on training set:  0.6238219895287959 	f1 training set:  0.6108031653771553
# Accuracy on test set:  0.5447120418848167 	f1 test set:  0.530830225363079
#
# Random_forest with 3 trees and 12 depth
# ----------------------------------------
# Accuracy on training set:  0.6517015706806283 	f1 training set:  0.6432507405494415
# Accuracy on test set:  0.5394764397905759 	f1 test set:  0.5277423553311837
#
# Random_forest with 3 trees and 13 depth
# ----------------------------------------
# Accuracy on training set:  0.6829842931937172 	f1 training set:  0.677487620864858
# Accuracy on test set:  0.5368586387434555 	f1 test set:  0.5289644316199338
#
# Random_forest with 3 trees and 14 depth
# ----------------------------------------
# Accuracy on training set:  0.7142146596858638 	f1 training set:  0.710336242040653
# Accuracy on test set:  0.5236649214659685 	f1 test set:  0.516804896374246
#
# Random_forest with 4 trees and 3 depth
# ----------------------------------------
# Accuracy on training set:  0.5191884816753927 	f1 training set:  0.4562649441142349
# Accuracy on test set:  0.5100523560209425 	f1 test set:  0.4489530750859346
#
# Random_forest with 4 trees and 4 depth
# ----------------------------------------
# Accuracy on training set:  0.5161518324607329 	f1 training set:  0.4852416469636977
# Accuracy on test set:  0.5075392670157068 	f1 test set:  0.47876935698719736
#
# Random_forest with 4 trees and 5 depth
# ----------------------------------------
# Accuracy on training set:  0.528586387434555 	f1 training set:  0.47789228701778463
# Accuracy on test set:  0.5247120418848168 	f1 test set:  0.47646679970421846
#
# Random_forest with 4 trees and 6 depth
# ----------------------------------------
# Accuracy on training set:  0.5407591623036649 	f1 training set:  0.5100986354163225
# Accuracy on test set:  0.5336125654450262 	f1 test set:  0.5055014188221382
#
# Random_forest with 4 trees and 7 depth
# ----------------------------------------
# Accuracy on training set:  0.5547905759162304 	f1 training set:  0.5301946310738977
# Accuracy on test set:  0.5425130890052356 	f1 test set:  0.5191603832157723
#
# Random_forest with 4 trees and 8 depth
# ----------------------------------------
# Accuracy on training set:  0.5701832460732984 	f1 training set:  0.5516777069404599
# Accuracy on test set:  0.545759162303665 	f1 test set:  0.5281469549980867
#
# Random_forest with 4 trees and 9 depth
# ----------------------------------------
# Accuracy on training set:  0.5898952879581152 	f1 training set:  0.5757830366095145
# Accuracy on test set:  0.5514136125654451 	f1 test set:  0.5373755819066292
#
# Random_forest with 4 trees and 10 depth
# ----------------------------------------
# Accuracy on training set:  0.6086125654450262 	f1 training set:  0.5941321566998351
# Accuracy on test set:  0.5481675392670157 	f1 test set:  0.5335104004066088
#
# Random_forest with 4 trees and 11 depth
# ----------------------------------------
# Accuracy on training set:  0.633455497382199 	f1 training set:  0.619826609215104
# Accuracy on test set:  0.5553926701570681 	f1 test set:  0.5392169906250651
#
# Random_forest with 4 trees and 12 depth
# ----------------------------------------
# Accuracy on training set:  0.6653664921465968 	f1 training set:  0.6557842867047166
# Accuracy on test set:  0.542303664921466 	f1 test set:  0.5299709808782886
#
# Random_forest with 4 trees and 13 depth
# ----------------------------------------
# Accuracy on training set:  0.6942670157068063 	f1 training set:  0.6871469555133896
# Accuracy on test set:  0.5356020942408377 	f1 test set:  0.5243151055814798
#
# Random_forest with 4 trees and 14 depth
# ----------------------------------------
# Accuracy on training set:  0.7303664921465969 	f1 training set:  0.7261309768045763
# Accuracy on test set:  0.5278534031413613 	f1 test set:  0.5204111229291638
#
# Random_forest with 5 trees and 3 depth
# ----------------------------------------
# Accuracy on training set:  0.5047120418848168 	f1 training set:  0.45716846302087055
# Accuracy on test set:  0.5021989528795812 	f1 test set:  0.4562360667869627
#
# Random_forest with 5 trees and 4 depth
# ----------------------------------------
# Accuracy on training set:  0.5214659685863874 	f1 training set:  0.47008392878157246
# Accuracy on test set:  0.5164397905759163 	f1 test set:  0.46728679309127097
#
# Random_forest with 5 trees and 5 depth
# ----------------------------------------
# Accuracy on training set:  0.5316492146596858 	f1 training set:  0.4949787929774447
# Accuracy on test set:  0.526282722513089 	f1 test set:  0.49076637621366165
#
# Random_forest with 5 trees and 6 depth
# ----------------------------------------
# Accuracy on training set:  0.5503403141361256 	f1 training set:  0.5248632557598955
# Accuracy on test set:  0.5403141361256545 	f1 test set:  0.5175705509232071
#
# Random_forest with 5 trees and 7 depth
# ----------------------------------------
# Accuracy on training set:  0.5601570680628273 	f1 training set:  0.5383675335775818
# Accuracy on test set:  0.5495287958115184 	f1 test set:  0.5299950669477417
#
# Random_forest with 5 trees and 8 depth
# ----------------------------------------
# Accuracy on training set:  0.5725130890052356 	f1 training set:  0.551223475612037
# Accuracy on test set:  0.5516230366492146 	f1 test set:  0.5312101767457941
#
# Random_forest with 5 trees and 9 depth
# ----------------------------------------
# Accuracy on training set:  0.5902617801047121 	f1 training set:  0.5726921630594529
# Accuracy on test set:  0.5556020942408377 	f1 test set:  0.537692978291944
#
# Random_forest with 5 trees and 10 depth
# ----------------------------------------
# Accuracy on training set:  0.6156020942408377 	f1 training set:  0.6007412582184298
# Accuracy on test set:  0.5524607329842932 	f1 test set:  0.5362563241131217
#
# Random_forest with 5 trees and 11 depth
# ----------------------------------------
# Accuracy on training set:  0.6371465968586387 	f1 training set:  0.6231393408652945
# Accuracy on test set:  0.5495287958115184 	f1 test set:  0.5337349289074385
#
# Random_forest with 5 trees and 12 depth
# ----------------------------------------
# Accuracy on training set:  0.6678534031413612 	f1 training set:  0.6576488969771852
# Accuracy on test set:  0.5499476439790576 	f1 test set:  0.5362200163626264
# Random_forest with 5 trees and 13 depth
# ----------------------------------------
# Accuracy on training set:  0.7049476439790576 	f1 training set:  0.698198905333431
# Accuracy on test set:  0.5458638743455497 	f1 test set:  0.5339964025778408
#
# Random_forest with 5 trees and 14 depth
# ----------------------------------------
# Accuracy on training set:  0.7326178010471204 	f1 training set:  0.7277165813330586
# Accuracy on test set:  0.5419895287958115 	f1 test set:  0.5324338928890987
#
# Random_forest with 6 trees and 3 depth
# ----------------------------------------
# Accuracy on training set:  0.4957591623036649 	f1 training set:  0.42477300287927083
# Accuracy on test set:  0.48942408376963353 	f1 test set:  0.4189218820318768
#
# Random_forest with 6 trees and 4 depth
# ----------------------------------------
# Accuracy on training set:  0.5253403141361257 	f1 training set:  0.48362402351312567
# Accuracy on test set:  0.5215706806282723 	f1 test set:  0.48094664054883485
#
# Random_forest with 6 trees and 5 depth
# ----------------------------------------
# Accuracy on training set:  0.538979057591623 	f1 training set:  0.5020285413527109
# Accuracy on test set:  0.5351832460732985 	f1 test set:  0.5004849892502504
#
# Random_forest with 6 trees and 6 depth
# ----------------------------------------
# Accuracy on training set:  0.555759162303665 	f1 training set:  0.5328627401482235
# Accuracy on test set:  0.5436649214659686 	f1 test set:  0.5228865375170498
#
# Random_forest with 6 trees and 7 depth
# ----------------------------------------
# Accuracy on training set:  0.5616753926701571 	f1 training set:  0.5314311286194592
# Accuracy on test set:  0.5447120418848167 	f1 test set:  0.5151002453695475
#
# Random_forest with 6 trees and 8 depth
# ----------------------------------------
# Accuracy on training set:  0.573979057591623 	f1 training set:  0.5511353703235887
# Accuracy on test set:  0.5504712041884817 	f1 test set:  0.5286390197168103
#
# Random_forest with 6 trees and 9 depth
# ----------------------------------------
# Accuracy on training set:  0.5902617801047121 	f1 training set:  0.5724289036562504
# Accuracy on test set:  0.5543455497382199 	f1 test set:  0.5359044533675817
#
# Random_forest with 6 trees and 10 depth
# ----------------------------------------
# Accuracy on training set:  0.616151832460733 	f1 training set:  0.5983846871743107
# Accuracy on test set:  0.5570680628272251 	f1 test set:  0.5368747177561602
#
# Random_forest with 6 trees and 11 depth
# ----------------------------------------
# Accuracy on training set:  0.636544502617801 	f1 training set:  0.6237948453703599
# Accuracy on test set:  0.5595811518324607 	f1 test set:  0.5454112390606656
#
# Random_forest with 6 trees and 12 depth
# ----------------------------------------
# Accuracy on training set:  0.6719895287958115 	f1 training set:  0.661837951451646
# Accuracy on test set:  0.5568586387434555 	f1 test set:  0.5431633388447545
#
# Random_forest with 6 trees and 13 depth
# ----------------------------------------
# Accuracy on training set:  0.7096858638743455 	f1 training set:  0.7025740909005362
# Accuracy on test set:  0.5521465968586388 	f1 test set:  0.5396980499363502
#
# Random_forest with 6 trees and 14 depth
# ----------------------------------------
# Accuracy on training set:  0.7600785340314136 	f1 training set:  0.7566047087530391
# Accuracy on test set:  0.5420942408376963 	f1 test set:  0.5335517267444854
#
# Random_forest with 7 trees and 3 depth
# ----------------------------------------
# Accuracy on training set:  0.5118848167539267 	f1 training set:  0.458580440470081
# Accuracy on test set:  0.5028272251308901 	f1 test set:  0.4518597386617233
#
# Random_forest with 7 trees and 4 depth
# ----------------------------------------
# Accuracy on training set:  0.5162303664921466 	f1 training set:  0.4827998541459547
# Accuracy on test set:  0.5119371727748692 	f1 test set:  0.4809359074182048
#
# Random_forest with 7 trees and 5 depth
# ----------------------------------------
# Accuracy on training set:  0.5267277486910995 	f1 training set:  0.49447587179759395
# Accuracy on test set:  0.5235602094240838 	f1 test set:  0.4925675156215449
#
# Random_forest with 7 trees and 6 depth
# ----------------------------------------
# Accuracy on training set:  0.552041884816754 	f1 training set:  0.5226975615489424
# Accuracy on test set:  0.5394764397905759 	f1 test set:  0.5128134009851301
#
# Random_forest with 7 trees and 7 depth
# ----------------------------------------
# Accuracy on training set:  0.5640314136125655 	f1 training set:  0.5350146452549699
# Accuracy on test set:  0.545759162303665 	f1 test set:  0.5179019286105264
#
# Random_forest with 7 trees and 8 depth
# ----------------------------------------
# Accuracy on training set:  0.5769895287958116 	f1 training set:  0.5521990950848175
# Accuracy on test set:  0.5528795811518324 	f1 test set:  0.528588625200518
#
# Random_forest with 7 trees and 9 depth
# ----------------------------------------
# Accuracy on training set:  0.5945026178010471 	f1 training set:  0.5743151696678451
# Accuracy on test set:  0.5645026178010472 	f1 test set:  0.5447039949669962
#
# Random_forest with 7 trees and 10 depth
# ----------------------------------------
# Accuracy on training set:  0.6192931937172775 	f1 training set:  0.6018803398105691
# Accuracy on test set:  0.5607329842931937 	f1 test set:  0.5421537004497551
#
# Random_forest with 7 trees and 11 depth
# ----------------------------------------
# Accuracy on training set:  0.6464921465968586 	f1 training set:  0.6314192659777036
# Accuracy on test set:  0.5561256544502617 	f1 test set:  0.5376272415137249
#
# Random_forest with 7 trees and 12 depth
# ----------------------------------------
# Accuracy on training set:  0.6800261780104712 	f1 training set:  0.670128274058728
# Accuracy on test set:  0.5552879581151833 	f1 test set:  0.5415951795302866
#
# Random_forest with 7 trees and 13 depth
# ----------------------------------------
# Accuracy on training set:  0.7133769633507854 	f1 training set:  0.7056628111443269
# Accuracy on test set:  0.5496335078534031 	f1 test set:  0.5362765713256544
#
# Random_forest with 7 trees and 14 depth
# ----------------------------------------
# Accuracy on training set:  0.7696596858638743 	f1 training set:  0.7657841091405294
# Accuracy on test set:  0.5460732984293194 	f1 test set:  0.5349490944043568
#
# Random_forest with 8 trees and 3 depth
# ----------------------------------------
# Accuracy on training set:  0.5009685863874346 	f1 training set:  0.43050985522134516
# Accuracy on test set:  0.49643979057591625 	f1 test set:  0.42767729728736015
#
# Random_forest with 8 trees and 4 depth
# ----------------------------------------
# Accuracy on training set:  0.5218586387434555 	f1 training set:  0.479976054173879
# Accuracy on test set:  0.5174869109947644 	f1 test set:  0.4803613967820244
#
# Random_forest with 8 trees and 5 depth
# ----------------------------------------
# Accuracy on training set:  0.5360994764397906 	f1 training set:  0.5032986730484338
# Accuracy on test set:  0.5315183246073298 	f1 test set:  0.5009501846768837
#
# Random_forest with 8 trees and 6 depth
# ----------------------------------------
# Accuracy on training set:  0.552696335078534 	f1 training set:  0.5230282743434211
# Accuracy on test set:  0.5421989528795812 	f1 test set:  0.514609181121943
#
# Random_forest with 8 trees and 7 depth
# ----------------------------------------
# Accuracy on training set:  0.5624083769633508 	f1 training set:  0.5375957669129541
# Accuracy on test set:  0.5468062827225131 	f1 test set:  0.5228035541135786
#
# Random_forest with 8 trees and 8 depth
# ----------------------------------------
# Accuracy on training set:  0.5776701570680628 	f1 training set:  0.5520019314702361
# Accuracy on test set:  0.5552879581151833 	f1 test set:  0.5307549034445824
#
# Random_forest with 8 trees and 9 depth
# ----------------------------------------
# Accuracy on training set:  0.5982460732984293 	f1 training set:  0.5771526194577111
# Accuracy on test set:  0.5583246073298429 	f1 test set:  0.5376746891708285
#
# Random_forest with 8 trees and 10 depth
# ----------------------------------------
# Accuracy on training set:  0.6160471204188481 	f1 training set:  0.5984739125856727
# Accuracy on test set:  0.5641884816753927 	f1 test set:  0.5454981574140189
# Random_forest with 8 trees and 11 depth
# ----------------------------------------
# Accuracy on training set:  0.6460732984293194 	f1 training set:  0.6337533315090911
# Accuracy on test set:  0.5642931937172775 	f1 test set:  0.5484961601587868
#
# Random_forest with 8 trees and 12 depth
# ----------------------------------------
# Accuracy on training set:  0.6786125654450261 	f1 training set:  0.668857806502948
# Accuracy on test set:  0.5630366492146597 	f1 test set:  0.5493743975408977
#
# Random_forest with 8 trees and 13 depth
# ----------------------------------------
# Accuracy on training set:  0.7200523560209424 	f1 training set:  0.7125286264132046
# Accuracy on test set:  0.553717277486911 	f1 test set:  0.5404680693529643
#
# Random_forest with 8 trees and 14 depth
# ----------------------------------------
# Accuracy on training set:  0.7736649214659685 	f1 training set:  0.7698636426234408
# Accuracy on test set:  0.5518324607329843 	f1 test set:  0.5421977352337933
#
# Random_forest with 9 trees and 3 depth
# ----------------------------------------
# Accuracy on training set:  0.5048952879581152 	f1 training set:  0.4520545126282096
# Accuracy on test set:  0.49989528795811516 	f1 test set:  0.44874267184151884
#
# Random_forest with 9 trees and 4 depth
# ----------------------------------------
# Accuracy on training set:  0.5284031413612565 	f1 training set:  0.47737313495038386
# Accuracy on test set:  0.5243979057591623 	f1 test set:  0.47547258993684355
#
# Random_forest with 9 trees and 5 depth
# ----------------------------------------
# Accuracy on training set:  0.5268848167539267 	f1 training set:  0.4935889991810836
# Accuracy on test set:  0.5203141361256545 	f1 test set:  0.4898522630881894
#
# Random_forest with 9 trees and 6 depth
# ----------------------------------------
# Accuracy on training set:  0.5529842931937172 	f1 training set:  0.5220381844603331
# Accuracy on test set:  0.5452356020942408 	f1 test set:  0.5178814409048335
#
# Random_forest with 9 trees and 7 depth
# ----------------------------------------
# Accuracy on training set:  0.5641884816753927 	f1 training set:  0.5364911663811658
# Accuracy on test set:  0.5523560209424084 	f1 test set:  0.5261577804175145
#
# Random_forest with 9 trees and 8 depth
# ----------------------------------------
# Accuracy on training set:  0.575759162303665 	f1 training set:  0.5486957011904469
# Accuracy on test set:  0.5528795811518324 	f1 test set:  0.5269732123602274
#
# Random_forest with 9 trees and 9 depth
# ----------------------------------------
# Accuracy on training set:  0.5962303664921466 	f1 training set:  0.5756294563739879
# Accuracy on test set:  0.5601047120418848 	f1 test set:  0.5403539147766704
#
# Random_forest with 9 trees and 10 depth
# ----------------------------------------
# Accuracy on training set:  0.6212565445026178 	f1 training set:  0.6021197088799164
# Accuracy on test set:  0.5633507853403141 	f1 test set:  0.5440929515186986
#
# Random_forest with 9 trees and 11 depth
# ----------------------------------------
# Accuracy on training set:  0.6400785340314136 	f1 training set:  0.6262648325186613
# Accuracy on test set:  0.5607329842931937 	f1 test set:  0.544250864116499
#
# Random_forest with 9 trees and 12 depth
# ----------------------------------------
# Accuracy on training set:  0.6873821989528796 	f1 training set:  0.6766864859661113
# Accuracy on test set:  0.5625130890052356 	f1 test set:  0.5476753821919972
#
# Random_forest with 9 trees and 13 depth
# ----------------------------------------
# Accuracy on training set:  0.7250785340314136 	f1 training set:  0.718166921154891
# Accuracy on test set:  0.5585340314136126 	f1 test set:  0.5449846807600209
#
# Random_forest with 9 trees and 14 depth
# ----------------------------------------
# Accuracy on training set:  0.7690052356020942 	f1 training set:  0.7646937479420246
# Accuracy on test set:  0.5585340314136126 	f1 test set:  0.5464798947772588
#
# Random_forest with 10 trees and 3 depth
# ----------------------------------------
# Accuracy on training set:  0.5147643979057591 	f1 training set:  0.4667571861375716
# Accuracy on test set:  0.5122513089005235 	f1 test set:  0.4674600239362233
#
# Random_forest with 10 trees and 4 depth
# ----------------------------------------
# Accuracy on training set:  0.5260471204188482 	f1 training set:  0.48061726749112865
# Accuracy on test set:  0.5219895287958115 	f1 test set:  0.4800389380189085
#
# Random_forest with 10 trees and 5 depth
# ----------------------------------------
# Accuracy on training set:  0.5312827225130891 	f1 training set:  0.4860849430273487
# Accuracy on test set:  0.5242931937172775 	f1 test set:  0.48168646691636624
#
# Random_forest with 10 trees and 6 depth
# ----------------------------------------
# Accuracy on training set:  0.5425392670157068 	f1 training set:  0.5050833609903203
# Accuracy on test set:  0.5354973821989529 	f1 test set:  0.49941916743213616
#
# Random_forest with 10 trees and 7 depth
# ----------------------------------------
# Accuracy on training set:  0.5645549738219895 	f1 training set:  0.5371209179050725
# Accuracy on test set:  0.5454450261780105 	f1 test set:  0.519326127491646
#
# Random_forest with 10 trees and 8 depth
# ----------------------------------------
# Accuracy on training set:  0.5824083769633508 	f1 training set:  0.5567164281151509
# Accuracy on test set:  0.5636649214659686 	f1 test set:  0.5395516521908212
#
# Random_forest with 10 trees and 9 depth
# ----------------------------------------
# Accuracy on training set:  0.596544502617801 	f1 training set:  0.5750022756117353
# Accuracy on test set:  0.5584293193717278 	f1 test set:  0.5351322426493962
#
# Random_forest with 10 trees and 10 depth
# ----------------------------------------
# Accuracy on training set:  0.6155497382198953 	f1 training set:  0.5976800580187941
# Accuracy on test set:  0.5565445026178011 	f1 test set:  0.5375265980769867
#
# Random_forest with 10 trees and 11 depth
# ----------------------------------------
# Accuracy on training set:  0.6460209424083769 	f1 training set:  0.6311602318752089
# Accuracy on test set:  0.5640837696335078 	f1 test set:  0.5479603477726672
#
# Random_forest with 10 trees and 12 depth
# ----------------------------------------
# Accuracy on training set:  0.6875392670157068 	f1 training set:  0.6768647307002044
# Accuracy on test set:  0.5646073298429319 	f1 test set:  0.5489136357828219
#
# Random_forest with 10 trees and 13 depth
# ----------------------------------------
# Accuracy on training set:  0.7308638743455498 	f1 training set:  0.723475917241427
# Accuracy on test set:  0.5594764397905759 	f1 test set:  0.5458867506922441
#
# Random_forest with 10 trees and 14 depth
# ----------------------------------------
# Accuracy on training set:  0.7747382198952879 	f1 training set:  0.7705018459047113
# Accuracy on test set:  0.5569633507853403 	f1 test set:  0.5446294273711867
#
# Random_forest with 11 trees and 3 depth
# ----------------------------------------
# Accuracy on training set:  0.5082984293193717 	f1 training set:  0.46579975228904774
# Accuracy on test set:  0.5033507853403142 	f1 test set:  0.4632415967891188
#
# Random_forest with 11 trees and 4 depth
# ----------------------------------------
# Accuracy on training set:  0.5349214659685864 	f1 training set:  0.48653360032639553
# Accuracy on test set:  0.5281675392670158 	f1 test set:  0.4802749033915267
#
# Random_forest with 11 trees and 5 depth
# ----------------------------------------
# Accuracy on training set:  0.5417539267015706 	f1 training set:  0.5031241703322078
# Accuracy on test set:  0.5299476439790576 	f1 test set:  0.4938198176325175
#
# Random_forest with 11 trees and 6 depth
# ----------------------------------------
# Accuracy on training set:  0.5509424083769634 	f1 training set:  0.5168255155167379
# Accuracy on test set:  0.5442931937172775 	f1 test set:  0.5131606315230619
#
# Random_forest with 11 trees and 7 depth
# ----------------------------------------
# Accuracy on training set:  0.5689528795811518 	f1 training set:  0.5388198021740664
# Accuracy on test set:  0.5531937172774869 	f1 test set:  0.5248733603137755
#
# Random_forest with 11 trees and 8 depth
# ----------------------------------------
# Accuracy on training set:  0.5816753926701571 	f1 training set:  0.5569865942036435
# Accuracy on test set:  0.558848167539267 	f1 test set:  0.5354086306566951
# Random_forest with 11 trees and 9 depth
# ----------------------------------------
# Accuracy on training set:  0.6012303664921466 	f1 training set:  0.5813251885309103
# Accuracy on test set:  0.5631413612565445 	f1 test set:  0.5425019236804922
#
# Random_forest with 11 trees and 10 depth
# ----------------------------------------
# Accuracy on training set:  0.6218324607329843 	f1 training set:  0.6057571673458761
# Accuracy on test set:  0.5627225130890052 	f1 test set:  0.544102494467634
#
# Random_forest with 11 trees and 11 depth
# ----------------------------------------
# Accuracy on training set:  0.6470157068062827 	f1 training set:  0.6333862312391065
# Accuracy on test set:  0.56 	f1 test set:  0.5442466480235215
#
# Random_forest with 11 trees and 12 depth
# ----------------------------------------
# Accuracy on training set:  0.6848167539267016 	f1 training set:  0.6736324622037719
# Accuracy on test set:  0.5594764397905759 	f1 test set:  0.5418704626575749
#
# Random_forest with 11 trees and 13 depth
# ----------------------------------------
# Accuracy on training set:  0.7238743455497382 	f1 training set:  0.7160892813331494
# Accuracy on test set:  0.5651308900523561 	f1 test set:  0.5518167946603276
#
# Random_forest with 11 trees and 14 depth
# ----------------------------------------
# Accuracy on training set:  0.7818848167539267 	f1 training set:  0.7779165856491833
# Accuracy on test set:  0.5532984293193717 	f1 test set:  0.5413574945618329
#
# Random_forest with 12 trees and 3 depth
# ----------------------------------------
# Accuracy on training set:  0.5083769633507853 	f1 training set:  0.4485911160079688
# Accuracy on test set:  0.49947643979057593 	f1 test set:  0.4415746316635377
#
# Random_forest with 12 trees and 4 depth
# ----------------------------------------
# Accuracy on training set:  0.5244240837696335 	f1 training set:  0.4872378069504488
# Accuracy on test set:  0.5211518324607329 	f1 test set:  0.4869647699642984
#
# Random_forest with 12 trees and 5 depth
# ----------------------------------------
# Accuracy on training set:  0.5369895287958115 	f1 training set:  0.4990121770356781
# Accuracy on test set:  0.5297382198952879 	f1 test set:  0.4946644029654158
#
# Random_forest with 12 trees and 6 depth
# ----------------------------------------
# Accuracy on training set:  0.5550261780104712 	f1 training set:  0.5298027074622073
# Accuracy on test set:  0.5433507853403141 	f1 test set:  0.5200539700601686
#
# Random_forest with 12 trees and 7 depth
# ----------------------------------------
# Accuracy on training set:  0.5642670157068063 	f1 training set:  0.5352767347297864
# Accuracy on test set:  0.549109947643979 	f1 test set:  0.5222681235071219
#
# Random_forest with 12 trees and 8 depth
# ----------------------------------------
# Accuracy on training set:  0.5831675392670157 	f1 training set:  0.5558899137406603
# Accuracy on test set:  0.56 	f1 test set:  0.5323622228977478
#
# Random_forest with 12 trees and 9 depth
# ----------------------------------------
# Accuracy on training set:  0.5970157068062827 	f1 training set:  0.5768779376213646
# Accuracy on test set:  0.5586387434554974 	f1 test set:  0.5385281578340111
#
# Random_forest with 12 trees and 10 depth
# ----------------------------------------
# Accuracy on training set:  0.6201570680628272 	f1 training set:  0.6017373984055663
# Accuracy on test set:  0.5617801047120419 	f1 test set:  0.5425213575449894
#
# Random_forest with 12 trees and 11 depth
# ----------------------------------------
# Accuracy on training set:  0.6562565445026178 	f1 training set:  0.6436027904172409
# Accuracy on test set:  0.5659685863874345 	f1 test set:  0.5503012160336096
#
# Random_forest with 12 trees and 12 depth
# ----------------------------------------
# Accuracy on training set:  0.6901047120418848 	f1 training set:  0.6796277767380218
# Accuracy on test set:  0.5634554973821989 	f1 test set:  0.5481076661087247
#
# Random_forest with 12 trees and 13 depth
# ----------------------------------------
# Accuracy on training set:  0.7369633507853404 	f1 training set:  0.7303114346393739
# Accuracy on test set:  0.5625130890052356 	f1 test set:  0.5500003421175212
#
# Random_forest with 12 trees and 14 depth
# ----------------------------------------
# Accuracy on training set:  0.7795549738219896 	f1 training set:  0.7751325281081652
# Accuracy on test set:  0.5632460732984294 	f1 test set:  0.5502892803900366
#
# Random_forest with 13 trees and 3 depth
# ----------------------------------------
# Accuracy on training set:  0.5166230366492146 	f1 training set:  0.4608729681100714
# Accuracy on test set:  0.5100523560209425 	f1 test set:  0.4556098797468249
#
# Random_forest with 13 trees and 4 depth
# ----------------------------------------
# Accuracy on training set:  0.5245287958115183 	f1 training set:  0.48175605320689924
# Accuracy on test set:  0.5182198952879581 	f1 test set:  0.47804223207855484
#
# Random_forest with 13 trees and 5 depth
# ----------------------------------------
# Accuracy on training set:  0.5409162303664922 	f1 training set:  0.5037045760263182
# Accuracy on test set:  0.5364397905759162 	f1 test set:  0.5024626508897637
#
# Random_forest with 13 trees and 6 depth
# ----------------------------------------
# Accuracy on training set:  0.5523821989528795 	f1 training set:  0.5198765145610802
# Accuracy on test set:  0.5419895287958115 	f1 test set:  0.5126552016745982
#
# Random_forest with 13 trees and 7 depth
# ----------------------------------------
# Accuracy on training set:  0.5645811518324607 	f1 training set:  0.5313443280342569
# Accuracy on test set:  0.5526701570680628 	f1 test set:  0.5202616735063147
#
# Random_forest with 13 trees and 8 depth
# ----------------------------------------
# Accuracy on training set:  0.5763612565445027 	f1 training set:  0.5520308344938997
# Accuracy on test set:  0.5532984293193717 	f1 test set:  0.5309133130805656
#
# Random_forest with 13 trees and 9 depth
# ----------------------------------------
# Accuracy on training set:  0.6001832460732984 	f1 training set:  0.5804876731681312
# Accuracy on test set:  0.5608376963350785 	f1 test set:  0.5408692006108713
#
# Random_forest with 13 trees and 10 depth
# ----------------------------------------
# Accuracy on training set:  0.6225916230366492 	f1 training set:  0.6044774384269179
# Accuracy on test set:  0.5683769633507854 	f1 test set:  0.549275425919433
#
# Random_forest with 13 trees and 11 depth
# ----------------------------------------
# Accuracy on training set:  0.6480628272251309 	f1 training set:  0.6336640741298527
# Accuracy on test set:  0.5652356020942408 	f1 test set:  0.5469530754339409
#
# Random_forest with 13 trees and 12 depth
# ----------------------------------------
# Accuracy on training set:  0.686282722513089 	f1 training set:  0.6756919442459857
# Accuracy on test set:  0.5671204188481676 	f1 test set:  0.5519613920346204
#
# Random_forest with 13 trees and 13 depth
# ----------------------------------------
# Accuracy on training set:  0.7301832460732984 	f1 training set:  0.7230863193438067
# Accuracy on test set:  0.5659685863874345 	f1 test set:  0.5523229152395647
#
# Random_forest with 13 trees and 14 depth
# ----------------------------------------
# Accuracy on training set:  0.7834816753926701 	f1 training set:  0.7794062846499775
# Accuracy on test set:  0.5631413612565445 	f1 test set:  0.550703393429446
#
# Random_forest with 14 trees and 3 depth
# ----------------------------------------
# Accuracy on training set:  0.5091884816753927 	f1 training set:  0.4456611097406661
# Accuracy on test set:  0.5001047120418848 	f1 test set:  0.4386709928831044
#
# Random_forest with 14 trees and 4 depth
# ----------------------------------------
# Accuracy on training set:  0.527303664921466 	f1 training set:  0.48215979622715255
# Accuracy on test set:  0.5233507853403141 	f1 test set:  0.48028013742015985
#
# Random_forest with 14 trees and 5 depth
# ----------------------------------------
# Accuracy on training set:  0.5442146596858639 	f1 training set:  0.5090747021158161
# Accuracy on test set:  0.5393717277486911 	f1 test set:  0.506817751002108
#
# Random_forest with 14 trees and 6 depth
# ----------------------------------------
# Accuracy on training set:  0.5497120418848167 	f1 training set:  0.5183475417509505
# Accuracy on test set:  0.5409424083769634 	f1 test set:  0.512219242879674
# Random_forest with 14 trees and 7 depth
# ----------------------------------------
# Accuracy on training set:  0.5646335078534032 	f1 training set:  0.5357272449043939
# Accuracy on test set:  0.5521465968586388 	f1 test set:  0.5244943457690271
#
# Random_forest with 14 trees and 8 depth
# ----------------------------------------
# Accuracy on training set:  0.5797120418848167 	f1 training set:  0.5567394193405015
# Accuracy on test set:  0.5565445026178011 	f1 test set:  0.5354344224751939
#
# Random_forest with 14 trees and 9 depth
# ----------------------------------------
# Accuracy on training set:  0.5969109947643979 	f1 training set:  0.5748448558852157
# Accuracy on test set:  0.5581151832460733 	f1 test set:  0.5366293938802303
#
# Random_forest with 14 trees and 10 depth
# ----------------------------------------
# Accuracy on training set:  0.6254450261780105 	f1 training set:  0.606807938948557
# Accuracy on test set:  0.5636649214659686 	f1 test set:  0.5425087403766097
#
# Random_forest with 14 trees and 11 depth
# ----------------------------------------
# Accuracy on training set:  0.6520680628272252 	f1 training set:  0.6386024835066987
# Accuracy on test set:  0.56282722513089 	f1 test set:  0.5456407107832016
#
# Random_forest with 14 trees and 12 depth
# ----------------------------------------
# Accuracy on training set:  0.6841623036649215 	f1 training set:  0.6733572418514228
# Accuracy on test set:  0.5654450261780105 	f1 test set:  0.5485696842125745
#
# Random_forest with 14 trees and 13 depth
# ----------------------------------------
# Accuracy on training set:  0.7365968586387435 	f1 training set:  0.7293169196770481
# Accuracy on test set:  0.5655497382198953 	f1 test set:  0.5503253910020802
#
# Random_forest with 14 trees and 14 depth
# ----------------------------------------
# Accuracy on training set:  0.7897120418848168 	f1 training set:  0.7856994450739175
# Accuracy on test set:  0.5618848167539267 	f1 test set:  0.5495311300102879

# %%
# In this case we are plotting 2 parameters, for that we make a colour graph
plt.imshow(Accuracy_test_forest)
plt.xlabel('Number of trees')
plt.ylabel('Depth')

ax = plt.gca()
ax.axes.xaxis.set_ticks([])
ax.axes.yaxis.set_ticks([])

plt.grid(True)
plt.colorbar()
plt.show()

# %% [markdown]
# As we can see in this case we obtain an accuracy of 0.56 using 11 trees and depth 11.

# %% [markdown]
# ### Model Results
# As we can see, the best results are obtained for the following metrics (*accuracy on test set*):
# - Random Forest with 11 trees and 11 depth: accuracy of ~ 0.56.
# - Logistic Regression with the parameter C = 100: accuracy of ~ 0.52.
# - Decision Tree with deph 11: accuracy ~ 0.54.
#
# Now we will decide which one to choose.

# %%
names = ["Logistic Regression", "Decision Tree", "Random Forest"]

classifiers = [
    LogisticRegression(solver='sag', multi_class='auto', max_iter=1000, C=100),
    DecisionTreeClassifier(max_depth=11),
    RandomForestClassifier(max_depth=11, n_estimators=11, max_features=3),
]

for name, clf in zip(names, classifiers):
        model = clf.fit(X_train, y_train)
        prediction_in = model.predict(X_train)
        accuracy_f1_in = f1_score(y_train, prediction_in, average='weighted')
        prediction_out = model.predict(X_test)
        accuracy_f1_out = f1_score(y_test, prediction_out, average='weighted')
        print() 
        print(name) 
        print("-" * 20)
        print("Accuracy on training set: ",model.score(X_train, y_train), "\tf1 training set: ", accuracy_f1_in )
        print("Accuracy on test set: ",model.score(X_test, y_test), "\tf1 test set: ", accuracy_f1_out )
        ROC_PRC_matrix(model, y_test, X_test)
        confusion_matrix(model, y_test, X_test)
# Out:
# Logistic Regression
# --------------------
# Accuracy on training set:  0.5175392670157068 	f1 training set:  0.48734049200977714
# Accuracy on test set:  0.5201047120418848 	f1 test set:  0.4896246160890367
#
# Decision Tree
# --------------------
# Accuracy on training set:  0.6167539267015707 	f1 training set:  0.606367174440301
# Accuracy on test set:  0.5420942408376963 	f1 test set:  0.5319316076665589
#
# Random Forest
# --------------------
# Accuracy on training set:  0.6501832460732985 	f1 training set:  0.635572530499807
# Accuracy on test set:  0.5621989528795811 	f1 test set:  0.5444932901178556

# %% [markdown]
# ## Selected Best Model:
# - Random Forest with 11 trees and 11 depth: accuracy of ~ 0.56.

# %% [markdown]
# ## Model analysis, features importance

# %%
tree = RandomForestClassifier(max_depth=11, n_estimators=11, max_features=3).fit(X_train, y_train)
importances = pd.Series(tree.feature_importances_, index=dataset.columns[dataset.columns != 'result_home_encoded'] )
importances.sort_values(ascending=True).plot(kind="barh")
# Out:
# <AxesSubplot:>
