# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
with sqlite3.connect("../laliga.sqlite") as conn:
    df = pd.read_sql("SELECT * FROM Matches", con = conn)

df = df.loc[-df.score.isnull()]

# %%
def parse_score(score_as_string):
        if score_as_string is None: 
            return None
        home_goals, away_goals = score_as_string.split(":")
        home_goals = int(home_goals)
        away_goals = int(away_goals)
        if home_goals > away_goals: 
            return "1"
        if away_goals > home_goals: 
            return "2" 
        else: 
            return "X"

# %%
df['result'] = df['score'].apply(parse_score)
df[['home_goals','away_goals']] = df['score'].str.split(":",expand=True)
df = df.astype({"home_goals": int, "away_goals": int})
df['Difference_goals'] = abs(df['home_goals'] - df['away_goals'])

# %%
index_match = []
for i in range(len(df)):
    index_match.append(i)

df["id_match"] = index_match

# %%
def identity_col(col):
    return col

def id_int(col):
    return col.astype(int)

# %%
def result(row): 
    if row["W"] == 1 : 
        return "W"
    if row["L"] == 1 :
        return "L"
    if row["T"] == 1: 
        return "T"
    else: 
        return "NaN"

# %%
df4 = df[['season','division','home_team','result','matchday','home_goals','away_team','away_goals','id_match']]
MatchdayStanding = df4.groupby(['season','division','matchday','home_team']).agg(
    GF = ('home_goals', sum),
    Away_team = ('away_team',identity_col),
    index_match = ('id_match', identity_col),
    GA = ('away_goals', sum),
    W = ('result', lambda x: x.eq('1').sum()),
    L = ('result', lambda x: x.eq('2').sum()),
    T = ('result', lambda x: x.eq('X').sum()),
).reset_index()
MatchdayStanding.rename({'home_team':'team'}, axis=1, inplace=True)
MatchdayStanding.sort_values(['season','division','team','matchday'])

df4_1 = df[["season","division","away_team","result",'matchday',"home_goals",'home_team',"away_goals",'id_match']]
df4_1 = df4_1.groupby(["season",'division','matchday',"away_team"], as_index=False).agg(
    GF = ("away_goals", sum),
    GA = ("home_goals", sum),
    index_match = ('id_match', identity_col),
    Away_team = ('home_team',identity_col),
    W_away = ('result', lambda x: x.eq('2').sum()),
    L_away = ('result', lambda x: x.eq('1').sum()),
    T_away = ('result', lambda x: x.eq('X').sum())
)
df4_1.sort_values(['season','division','away_team','matchday'])
df4_1.rename({'away_team': 'team', 'W_away': 'W', 'L_away': 'L', 'T_away': 'T'}, axis=1, inplace=True) 

MatchdayStanding = MatchdayStanding.append(df4_1).sort_values(['season','division','matchday'])
MatchdayStanding.reset_index()
MatchdayStanding.sort_values(['season','division','matchday'])
MatchdayStanding.reset_index()
MatchdayStanding['result'] = MatchdayStanding.apply(lambda row: result(row), axis=1)


MatchdayStanding['GD'] = MatchdayStanding['GF'] - MatchdayStanding['GA']

# Cummulative results
MatchdayStanding['GF'] = MatchdayStanding.groupby(["season",'division','team'], as_index=False)['GF'].cumsum()
MatchdayStanding['GA'] = MatchdayStanding.groupby(["season",'division','team'], as_index=False)['GA'].cumsum()
MatchdayStanding['W'] = MatchdayStanding.groupby(["season",'division','team'], as_index=False)['W'].cumsum()
MatchdayStanding['L'] = MatchdayStanding.groupby(["season",'division','team'], as_index=False)['L'].cumsum()
MatchdayStanding['T'] = MatchdayStanding.groupby(["season",'division','team'], as_index=False)['T'].cumsum()


MatchdayStanding['GD_cum'] = MatchdayStanding['GF'] - MatchdayStanding['GA']
MatchdayStanding['Pts'] = 3*MatchdayStanding['W'] + MatchdayStanding['T']

# Raking by matchday
team_count = MatchdayStanding.groupby(['season','division','matchday'])['team'].count().tolist()
rank_column = []
for i in team_count :
    j = list(range(1,i+1,1))
    rank_column += j

MatchdayStanding = MatchdayStanding.sort_values(['season','division','matchday', 'Pts', 'GD', 'GF'], ascending=[True,True, True, False, False, False])
MatchdayStanding['rank'] = rank_column

# %%
MatchdayStanding["GD_home"] = MatchdayStanding["GD_cum"]
MatchdayStanding["GD_away"] = - MatchdayStanding["GD_cum"]
MatchdayStanding = MatchdayStanding.drop(['GA','GF','GD'], axis=1)

# %%
MatchdayStanding['GD_home'] = MatchdayStanding.groupby(['season','division','team']).GD_home.shift()

# %%
MatchdayStanding['GD_away'] = MatchdayStanding.groupby(['season','division','team']).GD_away.shift()
# Out:
#        season  division  matchday             team        Away_team  \
# 4   1928-1929         1         1      Real Madrid        Catalunya
# 2   1928-1929         1         1        Barcelona           Racing
# 2   1928-1929         1         1         Espanyol       Real Unión
# 1   1928-1929         1         1  Athletic Madrid      Arenas Club
# 1   1928-1929         1         1         Donostia         Athletic
# 0   1928-1929         1         1         Athletic         Donostia
# 0   1928-1929         1         1      Arenas Club  Athletic Madrid
# 4   1928-1929         1         1       Real Unión         Espanyol
# 3   1928-1929         1         1           Racing        Barcelona
# 3   1928-1929         1         1        Catalunya      Real Madrid
# 9   1928-1929         1         2      Real Madrid        Barcelona
# 5   1928-1929         1         2         Athletic         Espanyol
# 6   1928-1929         1         2         Donostia  Athletic Madrid
# 8   1928-1929         1         2        Catalunya      Arenas Club
# 9   1928-1929         1         2       Real Unión           Racing
# 7   1928-1929         1         2        Barcelona      Real Madrid
# 6   1928-1929         1         2  Athletic Madrid         Donostia
# 7   1928-1929         1         2         Espanyol         Athletic
# 8   1928-1929         1         2           Racing       Real Unión
# 5   1928-1929         1         2      Arenas Club        Catalunya
# 14  1928-1929         1         3      Real Madrid  Athletic Madrid
# 10  1928-1929         1         3         Athletic           Racing
# 11  1928-1929         1         3         Donostia        Barcelona
# 12  1928-1929         1         3         Espanyol        Catalunya
# 14  1928-1929         1         3       Real Unión      Arenas Club
# 11  1928-1929         1         3  Athletic Madrid      Real Madrid
# 13  1928-1929         1         3        Catalunya         Espanyol
# 12  1928-1929         1         3        Barcelona         Donostia
# 10  1928-1929         1         3      Arenas Club       Real Unión
# 13  1928-1929         1         3           Racing         Athletic
#
#    index_match  W  L  T result  GD_cum  Pts  rank  GD_home  GD_away
# 4            2  1  0  0      W       5    3     1      NaN      NaN
# 2            4  1  0  0      W       2    3     2      NaN      NaN
# 2            1  1  0  0      W       1    3     3      NaN      NaN
# 1            0  1  0  0      W       1    3     4      NaN      NaN
# 1            3  0  0  1      T       0    1     5      NaN      NaN
# 0            3  0  0  1      T       0    1     6      NaN      NaN
# 0            0  0  1  0      L      -1    0     7      NaN      NaN
# 4            1  0  1  0      L      -1    0     8      NaN      NaN
# 3            4  0  1  0      L      -2    0     9      NaN      NaN
# 3            2  0  1  0      L      -5    0    10      NaN      NaN
# 9            5  2  0  0      W       6    6     1      5.0     -5.0
# 5            6  1  0  1      W       9    4     2      0.0      0.0
# 6            7  1  0  1      W       3    4     3      0.0      0.0
# 8            9  1  1  0      W      -2    3     4     -5.0      5.0
# 9            8  1  1  0      W       1    3     5     -1.0      1.0
# 7            5  1  1  0      L       1    3     6      2.0     -2.0
# 6            7  1  1  0      L      -2    3     7      1.0     -1.0
# 7            6  1  1  0      L      -8    3     8      1.0     -1.0
# 8            8  0  2  0      L      -4    0     9     -2.0      2.0
# 5            9  0  2  0      L      -4    0    10     -1.0      1.0
# 14          14  3  0  0      W       7    9     1      6.0     -6.0
# 10          13  2  0  1      W      13    7     2      9.0     -9.0
# 11          10  2  0  1      W       6    7     3      3.0     -3.0
# 12          11  2  1  0      W      -6    6     4     -8.0      8.0
# 14          12  1  1  1      T       1    4     5      1.0     -1.0
# 11          14  1  2  0      L      -3    3     6     -2.0      2.0
# 13          11  1  2  0      L      -4    3     7     -2.0      2.0
# 12          10  1  2  0      L      -2    3     8      1.0     -1.0
# 10          12  0  2  1      T      -4    1     9     -4.0      4.0
# 13          13  0  3  0      L      -8    0    10     -4.0      4.0

# %%
MatchdayStanding['rank'] = MatchdayStanding.groupby(['season','division','team'])['rank'].shift()

# %%
MatchdayStanding['W'] = MatchdayStanding.groupby(['season','division','team'])['W'].shift()
MatchdayStanding['T'] = MatchdayStanding.groupby(['season','division','team'])['T'].shift()
MatchdayStanding['L'] = MatchdayStanding.groupby(['season','division','team'])['L'].shift()

# %%
MatchdayStanding = MatchdayStanding.drop(['GD_cum','Pts'], axis=1)

# %%
MatchdayStanding
# Out:
#           season  division  matchday             team        Away_team  \
# 4      1928-1929         1         1      Real Madrid        Catalunya
# 2      1928-1929         1         1        Barcelona           Racing
# 2      1928-1929         1         1         Espanyol       Real Unión
# 1      1928-1929         1         1  Athletic Madrid      Arenas Club
# 1      1928-1929         1         1         Donostia         Athletic
# ...          ...       ...       ...              ...              ...
# 47995  2021-2022         2         3      Real Oviedo      CD Tenerife
# 47992  2021-2022         2         3          CD Lugo  Real Valladolid
# 47991  2021-2022         2         3       CD Leganés         UD Ibiza
# 47990  2021-2022         2         3        Burgos CF         SD Eibar
# 47989  2021-2022         2         3         Alcorcón        Málaga CF
#
#       index_match    W    L    T result  rank  GD_home  GD_away
# 4               2  NaN  NaN  NaN      W   NaN      NaN      NaN
# 2               4  NaN  NaN  NaN      W   NaN      NaN      NaN
# 2               1  NaN  NaN  NaN      W   NaN      NaN      NaN
# 1               0  NaN  NaN  NaN      W   NaN      NaN      NaN
# 1               3  NaN  NaN  NaN      T   NaN      NaN      NaN
# ...           ...  ...  ...  ...    ...   ...      ...      ...
# 47995       48234  0.0  1.0  1.0      T  17.0     -1.0      1.0
# 47992       48237  0.0  0.0  2.0      L  11.0      0.0      0.0
# 47991       48233  0.0  1.0  1.0      L  15.0     -1.0      1.0
# 47990       48239  0.0  1.0  1.0      L  16.0     -1.0      1.0
# 47989       48231  0.0  2.0  0.0      L  21.0     -3.0      3.0
#
# [95999 rows x 13 columns]

# %%
MatchdayStanding = MatchdayStanding.sort_values(['index_match'], ascending=[True])
MatchdayStanding_1 = MatchdayStanding.iloc[::2]
MatchdayStanding_2 = MatchdayStanding.iloc[1::2]

# %%
MatchdayStanding_1.head(10)
# Out:
#       season  division  matchday             team    Away_team index_match  \
# 1  1928-1929         1         1  Athletic Madrid  Arenas Club           0
# 2  1928-1929         1         1         Espanyol   Real Unión           1
# 4  1928-1929         1         1      Real Madrid    Catalunya           2
# 1  1928-1929         1         1         Donostia     Athletic           3
# 2  1928-1929         1         1        Barcelona       Racing           4
# 9  1928-1929         1         2      Real Madrid    Barcelona           5
# 5  1928-1929         1         2         Athletic     Espanyol           6
# 6  1928-1929         1         2  Athletic Madrid     Donostia           7
# 8  1928-1929         1         2           Racing   Real Unión           8
# 8  1928-1929         1         2        Catalunya  Arenas Club           9
#
#      W    L    T result  rank  GD_home  GD_away
# 1  NaN  NaN  NaN      W   NaN      NaN      NaN
# 2  NaN  NaN  NaN      W   NaN      NaN      NaN
# 4  NaN  NaN  NaN      W   NaN      NaN      NaN
# 1  NaN  NaN  NaN      T   NaN      NaN      NaN
# 2  NaN  NaN  NaN      W   NaN      NaN      NaN
# 9  1.0  0.0  0.0      W   1.0      5.0     -5.0
# 5  0.0  0.0  1.0      W   6.0      0.0      0.0
# 6  1.0  0.0  0.0      L   4.0      1.0     -1.0
# 8  0.0  1.0  0.0      L   9.0     -2.0      2.0
# 8  0.0  1.0  0.0      W  10.0     -5.0      5.0

# %%
MatchdayStanding_2.head(10)
# Out:
#       season  division  matchday         team        Away_team index_match  \
# 0  1928-1929         1         1  Arenas Club  Athletic Madrid           0
# 4  1928-1929         1         1   Real Unión         Espanyol           1
# 3  1928-1929         1         1    Catalunya      Real Madrid           2
# 0  1928-1929         1         1     Athletic         Donostia           3
# 3  1928-1929         1         1       Racing        Barcelona           4
# 7  1928-1929         1         2    Barcelona      Real Madrid           5
# 7  1928-1929         1         2     Espanyol         Athletic           6
# 6  1928-1929         1         2     Donostia  Athletic Madrid           7
# 9  1928-1929         1         2   Real Unión           Racing           8
# 5  1928-1929         1         2  Arenas Club        Catalunya           9
#
#      W    L    T result  rank  GD_home  GD_away
# 0  NaN  NaN  NaN      L   NaN      NaN      NaN
# 4  NaN  NaN  NaN      L   NaN      NaN      NaN
# 3  NaN  NaN  NaN      L   NaN      NaN      NaN
# 0  NaN  NaN  NaN      T   NaN      NaN      NaN
# 3  NaN  NaN  NaN      L   NaN      NaN      NaN
# 7  1.0  0.0  0.0      L   2.0      2.0     -2.0
# 7  1.0  0.0  0.0      L   3.0      1.0     -1.0
# 6  0.0  0.0  1.0      W   5.0      0.0      0.0
# 9  0.0  1.0  0.0      W   8.0     -1.0      1.0
# 5  0.0  1.0  0.0      L   7.0     -1.0      1.0
