# %%
import pandas as pd 
import numpy as np
from time import time
import seaborn as sns

# %%
import scikitplot as skplt

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from sklearn import preprocessing

from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt
from matplotlib import pyplot

import sys
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Dataset
#
# In this section we import our dataset (already processed and encoded) and check for correlated variables

# %% [markdown]
# The features we are interested in have to be as independent as possible from each other. Therefore, we are going to
# make sure that we don't have any correlated columns with a value higher than .95

# %%
dataset_sincambios
# Out:
#           season  division  matchday             team        Away_team    W  \
# 0      1928-1929         1         1      Arenas Club  Athletic Madrid  NaN
# 2      1928-1929         1         1         Espanyol       Real Unión  NaN
# 4      1928-1929         1         1      Real Madrid        Catalunya  NaN
# 1      1928-1929         1         1         Donostia         Athletic  NaN
# 2      1928-1929         1         1        Barcelona           Racing  NaN
# ...          ...       ...       ...              ...              ...  ...
# 47993  2021-2022         2         3           Girona     Ponferradina  1.0
# 47997  2021-2022         2         3       UD Almería    SD Amorebieta  2.0
# 47994  2021-2022         2         3  Real Valladolid          CD Lugo  1.0
# 47992  2021-2022         2         3   CF Fuenlabrada  Real Sociedad B  1.0
# 47990  2021-2022         2         3        Burgos CF         SD Eibar  0.0
#
#          L    T result  rank  GD_home  GD_away
# 0      NaN  NaN      L   NaN      NaN      NaN
# 2      NaN  NaN      W   NaN      NaN      NaN
# 4      NaN  NaN      W   NaN      NaN      NaN
# 1      NaN  NaN      T   NaN      NaN      NaN
# 2      NaN  NaN      W   NaN      NaN      NaN
# ...    ...  ...    ...   ...      ...      ...
# 47993  0.0  1.0      L   7.0      2.0     -2.0
# 47997  0.0  0.0      L   2.0      3.0     -3.0
# 47994  0.0  1.0      W   4.0      2.0     -2.0
# 47992  1.0  0.0      T  10.0      1.0     -1.0
# 47990  1.0  1.0      L  16.0     -1.0      1.0
#
# [48000 rows x 12 columns]

# %%
dataset_sincambios = pd.read_csv(r'..\reports\provisional.csv', index_col = 0)
dataset_sincambios = dataset_sincambios.drop('index_match', axis=1)
dataset_sincambios = dataset_sincambios.dropna()
dataset = dataset_sincambios.copy()

# %%
#dataset = dataset.drop(['home_GD_lm','away_GD_lm'], axis=1)
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
dataset = dataset.dropna()
categorical_variables = ["season", "team", "Away_team", "result"]
for col in categorical_variables:
    dataset[f"{col}_encoded"] = le.fit_transform(dataset[col])

# %%
dataset = dataset.drop(['team','Away_team','season','result','GD_away'], axis=1)

# %%
cor_matrix = dataset.corr().abs()
upper_tri = cor_matrix.where(np.triu(np.ones(cor_matrix.shape),k=1).astype(np.bool))

to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.95)]
print(); print(to_drop)
# Out:
# []

# %%
# Compute the correlation matrix
corr = dataset.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=False)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Automatic Variable Selection
# In order to have an automatic variable selection we can use a **model-based** feature selection. Consequently, we will use a supervised machine learning model to judge the importance of each feature.
#
# We will add some noise feature to our data and expect that the feature selection will identify the features that are non informative, removing the data features that are irrelevant.
#
# For that purpose, we will add as many noise features as we have and select the 50% that are more correlated. Then, we will discard the noise features. The variables selected can be shown belove: black are original features and white noise features

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier

dataset = dataset.dropna()
target = dataset.result_encoded
X = dataset[['division','matchday','season_encoded','home_team_encoded','away_team_encoded']]
#target = dataset.result
#X = dataset.loc[:, dataset.columns != 'result']

# get deterministic random numbers
rng = np.random.RandomState(42)
noise = rng.normal(size=(len(dataset), 4))
X_w_noise = np.hstack([X, noise])

X_train,X_test,y_train,y_test = train_test_split(X_w_noise, target, test_size=0.25)

select = SelectFromModel( RandomForestClassifier(n_estimators=100, random_state=42), threshold="median")

select.fit(X_train, y_train)
X_train = select.transform(X_train)
print("X_train.shape: {}".format(X_train.shape))
print("y_train.shape: {}".format(y_train.shape))

print("X_train_l1.shape: {}".format(X_train.shape))

mask = select.get_support()
# visualize the mask -- black is True, white is False
plt.matshow(mask.reshape(1, -1), cmap='gray_r')
plt.xlabel("Sample index")

X_test = select.transform(X_test)
# Out:
# X_train.shape: (36180, 5)
# y_train.shape: (36180,)
# X_train_l1.shape: (36180, 5)

# %% [markdown]
# ## Normal selection of variables and splitting data

# %%
target = dataset.result_encoded
X = dataset.loc[:, dataset.columns != "result_encoded"]
#X = dataset[['season','division','matchday','team','Away_team','W','GD_cum_before','rank_before']]
X_train,X_test,y_train,y_test = train_test_split(X, target, test_size=0.2, random_state=1)

# %% [markdown]
# ## Function to construct confusion matrix and ROC

# %%
#plot our results
def confusion_matrix(trained_model, y_test, X_test):
    Y_test_pred = trained_model.predict(X_test)

    fig = plt.figure(figsize=(15,6))
    ax1 = fig.add_subplot(121)
    skplt.metrics.plot_confusion_matrix(y_test, Y_test_pred,
                                        title="Confusion Matrix",
                                        cmap="Oranges",
                                        ax=ax1)

    ax2 = fig.add_subplot(122)
    skplt.metrics.plot_confusion_matrix(y_test, Y_test_pred,
                                        normalize=True,
                                        title="Confusion Matrix",
                                        cmap="Purples",
                                        ax=ax2)

def ROC_PRC_matrix(trained_model, y_test, X_test):    
    y_test_probs = trained_model.predict_proba(X_test)
    
    fig = plt.figure(figsize=(15,6))
    ax1 = fig.add_subplot(121)
    skplt.metrics.plot_roc_curve(y_test, y_test_probs,
                       title="Digits ROC Curve", figsize=(12,6), ax=ax1)
    
    ax2 = fig.add_subplot(122)
    skplt.metrics.plot_precision_recall_curve(y_test, y_test_probs,
                        title="Digits Precision-Recall Curve", figsize=(12,6), ax= ax2)

# %% [markdown]
# ## Estimations of parameters in models

# %%
from sklearn.svm import LinearSVC
linear_svm = LinearSVC().fit(X_train, y_train)
prediction_in = linear_svm.predict(X_train)
accuracy_r2_in = r2_score(y_train, prediction_in)
prediction_out = linear_svm.predict(X_test)
accuracy_r2_out = r2_score(y_test, prediction_out)
print() 
print("SVM") 
print("-" * 20)
print("Accuracy on training set: ",linear_svm.score(X_train, y_train), "\tR2 training set: ", accuracy_r2_in )
print("Accuracy on test set: ",linear_svm.score(X_test, y_test), "\tR2 test set: ", accuracy_r2_out )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12700/2153795385.py in <module>
#       1 from sklearn.svm import LinearSVC
# ----> 2 linear_svm = LinearSVC().fit(X_train, y_train)
#       3 prediction_in = linear_svm.predict(X_train)
#       4 accuracy_r2_in = r2_score(y_train, prediction_in)
#       5 prediction_out = linear_svm.predict(X_test)
#
# c:\users\jorge\appdata\local\programs\python\python39\lib\site-packages\sklearn\svm\_classes.py in fit(self, X, y, sample_weight)
#     244             raise ValueError("Penalty term must be positive; got (C=%r)" % self.C)
#     245
# --> 246         X, y = self._validate_data(
#     247             X,
#     248             y,
#
# c:\users\jorge\appdata\local\programs\python\python39\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     570                 y = check_array(y, **check_y_params)
#     571             else:
# --> 572                 X, y = check_X_y(X, y, **check_params)
#     573             out = X, y
#     574
#
# c:\users\jorge\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     954         raise ValueError("y cannot be None")
#     955
# --> 956     X = check_array(
#     957         X,
#     958         accept_sparse=accept_sparse,
#
# c:\users\jorge\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     736                     array = array.astype(dtype, casting="unsafe", copy=False)
#     737                 else:
# --> 738                     array = np.asarray(array, order=order, dtype=dtype)
#     739             except ComplexWarning as complex_warning:
#     740                 raise ValueError(
#
# c:\users\jorge\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in __array__(self, dtype)
#    1991
#    1992     def __array__(self, dtype: NpDtype | None = None) -> np.ndarray:
# -> 1993         return np.asarray(self._values, dtype=dtype)
#    1994
#    1995     def __array_wrap__(
#
# ValueError: could not convert string to float: '2000-2001'

# %%
# Looking for best parameter for logistic regression model
for C in [0.001, 0.01, 0.1, 1, 10, 100]:
    logreg = LogisticRegression(C=C).fit(X_train, y_train)
    prediction_in = logreg.predict(X_train)
    accuracy_r2_in = r2_score(y_train, prediction_in)
    prediction_out = logreg.predict(X_test)
    accuracy_r2_out = r2_score(y_test, prediction_out)
    print() 
    print("Logistic Regression with parameter ", C) 
    print("-" * 20)
    print("Accuracy on training set: ",logreg.score(X_train, y_train), "\tR2 training set: ", accuracy_r2_in )
    print("Accuracy on test set: ",logreg.score(X_test, y_test), "\tR2 test set: ", accuracy_r2_out )
# Out:
# Logistic Regression with parameter  0.001
# --------------------
# Accuracy on training set:  0.4082749326145553 	R2 training set:  -1.117862330946036
# Accuracy on test set:  0.4177447175506684 	R2 test set:  -1.0846008655505939
#
# Logistic Regression with parameter  0.01
# --------------------
# Accuracy on training set:  0.4095956873315364 	R2 training set:  -1.1183701159237422
# Accuracy on test set:  0.4161276412246658 	R2 test set:  -1.0915331671680546
#
# Logistic Regression with parameter  0.1
# --------------------
# Accuracy on training set:  0.4085714285714286 	R2 training set:  -1.1198572005013108
# Accuracy on test set:  0.4188227684346701 	R2 test set:  -1.075357796727313
#
# Logistic Regression with parameter  1
# --------------------
# Accuracy on training set:  0.40994609164420487 	R2 training set:  -1.1119139926357633
# Accuracy on test set:  0.4180681328158689 	R2 test set:  -1.080268177039681
#
# Logistic Regression with parameter  10
# --------------------
# Accuracy on training set:  0.4087870619946092 	R2 training set:  -1.1093387973916817
# Accuracy on test set:  0.416882276843467 	R2 test set:  -1.0818568294936823
#
# Logistic Regression with parameter  100
# --------------------
# Accuracy on training set:  0.41008086253369275 	R2 training set:  -1.1142352953909915
# Accuracy on test set:  0.4177447175506684 	R2 test set:  -1.0828677901462287

# %%
# Preprunning for decision tree model, avoiding overfitting
for depth in range(3,8):
    tree = DecisionTreeClassifier(max_depth=depth).fit(X_train, y_train)
    prediction_in = tree.predict(X_train)
    accuracy_r2_in = r2_score(y_train, prediction_in)
    prediction_out = tree.predict(X_test)
    accuracy_r2_out = r2_score(y_test, prediction_out)
    print() 
    print("Decision tree with depth ", depth) 
    print("-" * 20)
    print("Accuracy on training set: ",tree.score(X_train, y_train), "\tR2 training set: ", accuracy_r2_in )
    print("Accuracy on test set: ",tree.score(X_test, y_test), "\tR2 test set: ", accuracy_r2_out )
# Out:
# Decision tree with depth  3
# --------------------
# Accuracy on training set:  0.527285447761194 	R2 training set:  -0.7482987197355464
# Accuracy on test set:  0.5298507462686567 	R2 test set:  -0.7412019491066593
#
# Decision tree with depth  4
# --------------------
# Accuracy on training set:  0.5299803067993366 	R2 training set:  -0.7073791484896221
# Accuracy on test set:  0.5280887230514096 	R2 test set:  -0.7081531844725697
#
# Decision tree with depth  5
# --------------------
# Accuracy on training set:  0.5309131426202321 	R2 training set:  -0.7291712841130091
# Accuracy on test set:  0.5296434494195689 	R2 test set:  -0.7292108044164145
#
# Decision tree with depth  6
# --------------------
# Accuracy on training set:  0.533271144278607 	R2 training set:  -0.7093137936957186
# Accuracy on test set:  0.5303689883913765 	R2 test set:  -0.7167809593106726
#
# Decision tree with depth  7
# --------------------
# Accuracy on training set:  0.5360955638474295 	R2 training set:  -0.6926320416356049
# Accuracy on test set:  0.5303689883913765 	R2 test set:  -0.7071295501697439

# %%
# Random forest model

# We set max_depth = 5 as preprunning parameter
# We set max_features as sqrt of n_features to reduce overfitting (pag 102)

for trees in range(5,10):
    for depth in range(2,6):
        random_forest = RandomForestClassifier(max_depth=depth, n_estimators=trees, max_features=3).fit(X_train, y_train)
        prediction_in = random_forest.predict(X_train)
        accuracy_r2_in = r2_score(y_train, prediction_in)
        prediction_out = random_forest.predict(X_test)
        accuracy_r2_out = r2_score(y_test, prediction_out)
        print() 
        print(f"Random_forest with {trees} trees and {depth} depth") 
        print("-" * 40)
        print("Accuracy on training set: ",random_forest.score(X_train, y_train), "\tR2 training set: ", accuracy_r2_in )
        print("Accuracy on test set: ",random_forest.score(X_test, y_test), "\tR2 test set: ", accuracy_r2_out )
# Out:
# Random_forest with 5 trees and 2 depth
# ----------------------------------------
# Accuracy on training set:  0.41078167115902964 	R2 training set:  -1.1346192352103417
# Accuracy on test set:  0.41752910737386806 	R2 test set:  -1.1026537343460645
#
# Random_forest with 5 trees and 3 depth
# ----------------------------------------
# Accuracy on training set:  0.4130188679245283 	R2 training set:  -1.122577477167594
# Accuracy on test set:  0.4278783958602846 	R2 test set:  -1.0471953214063787
#
# Random_forest with 5 trees and 4 depth
# ----------------------------------------
# Accuracy on training set:  0.4151212938005391 	R2 training set:  -1.1112611262358554
# Accuracy on test set:  0.41720569210866754 	R2 test set:  -1.1043868097504297
#
# Random_forest with 5 trees and 5 depth
# ----------------------------------------
# Accuracy on training set:  0.41851752021563343 	R2 training set:  -1.0935249223716874
# Accuracy on test set:  0.41623544631306597 	R2 test set:  -1.1087194982613426
#
# Random_forest with 6 trees and 2 depth
# ----------------------------------------
# Accuracy on training set:  0.4087870619946092 	R2 training set:  -1.1453552604532735
# Accuracy on test set:  0.42065545493747303 	R2 test set:  -1.0859006721038678
#
# Random_forest with 6 trees and 3 depth
# ----------------------------------------
# Accuracy on training set:  0.40932614555256064 	R2 training set:  -1.142453632009238
# Accuracy on test set:  0.419361793876671 	R2 test set:  -1.0928329737213285
#
# Random_forest with 6 trees and 4 depth
# ----------------------------------------
# Accuracy on training set:  0.41059299191374665 	R2 training set:  -1.135634805165754
# Accuracy on test set:  0.41483398016386375 	R2 test set:  -1.117096029382441
#
# Random_forest with 6 trees and 5 depth
# ----------------------------------------
# Accuracy on training set:  0.42121293800539084 	R2 training set:  -1.078472724818253
# Accuracy on test set:  0.4208710651142734 	R2 test set:  -1.0834454819476838
#
# Random_forest with 7 trees and 2 depth
# ----------------------------------------
# Accuracy on training set:  0.40849056603773587 	R2 training set:  -1.1469511560974932
# Accuracy on test set:  0.41990081931867185 	R2 test set:  -1.0899445147140532
#
# Random_forest with 7 trees and 3 depth
# ----------------------------------------
# Accuracy on training set:  0.4136118598382749 	R2 training set:  -1.119385685879155
# Accuracy on test set:  0.4246442432082794 	R2 test set:  -1.0645260754500305
#
# Random_forest with 7 trees and 4 depth
# ----------------------------------------
# Accuracy on training set:  0.4159568733153639 	R2 training set:  -1.1070900353475541
# Accuracy on test set:  0.4228115567054765 	R2 test set:  -1.0739135672236753
#
# Random_forest with 7 trees and 5 depth
# ----------------------------------------
# Accuracy on training set:  0.4228571428571429 	R2 training set:  -1.0707108687304578
# Accuracy on test set:  0.4241052177662786 	R2 test set:  -1.0682810721594884
#
# Random_forest with 8 trees and 2 depth
# ----------------------------------------
# Accuracy on training set:  0.41204851752021565 	R2 training set:  -1.1278004083668582
# Accuracy on test set:  0.42496765847347995 	R2 test set:  -1.0627930000456653
#
# Random_forest with 8 trees and 3 depth
# ----------------------------------------
# Accuracy on training set:  0.41183288409703506 	R2 training set:  -1.1289610597444724
# Accuracy on test set:  0.42496765847347995 	R2 test set:  -1.0627930000456653
#
# Random_forest with 8 trees and 4 depth
# ----------------------------------------
# Accuracy on training set:  0.4181401617250674 	R2 training set:  -1.095012006949256
# Accuracy on test set:  0.4279862009486848 	R2 test set:  -1.0466176296049237
#
# Random_forest with 8 trees and 5 depth
# ----------------------------------------
# Accuracy on training set:  0.42161725067385447 	R2 training set:  -1.0768405588184828
# Accuracy on test set:  0.4239974126778784 	R2 test set:  -1.066692419705487
#
# Random_forest with 9 trees and 2 depth
# ----------------------------------------
# Accuracy on training set:  0.4075471698113208 	R2 training set:  -1.1520290058745553
# Accuracy on test set:  0.4188227684346701 	R2 test set:  -1.0957214327286038
#
# Random_forest with 9 trees and 3 depth
# ----------------------------------------
# Accuracy on training set:  0.4131266846361186 	R2 training set:  -1.1219971514787868
# Accuracy on test set:  0.42529107373868047 	R2 test set:  -1.0610599246413002
#
# Random_forest with 9 trees and 4 depth
# ----------------------------------------
# Accuracy on training set:  0.4160646900269542 	R2 training set:  -1.1061832764587929
# Accuracy on test set:  0.42270375161707635 	R2 test set:  -1.0749245278762216
#
# Random_forest with 9 trees and 5 depth
# ----------------------------------------
# Accuracy on training set:  0.4238544474393531 	R2 training set:  -1.0642547454424784
# Accuracy on test set:  0.4306813281586891 	R2 test set:  -1.0321753345685467

# %%
names = ["Logistic Regression", "Decision Tree", "Random Forest"]
         
classifiers = [
    #KNeighborsClassifier(3),
    LogisticRegression(),
    DecisionTreeClassifier(max_depth=1),
    RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1),
]


for name, clf in zip(names, classifiers):
        clf.fit(X_train, y_train)
        prediction_in = clf.predict(X_train)
        accuracy_r2_in = r2_score(y_train, prediction_in)
        prediction_out = clf.predict(X_test)
        accuracy_r2_out = r2_score(y_test, prediction_out)
        print() 
        print(name) 
        print("-" * 20)
        print("Accuracy on training set: ",clf.score(X_train, y_train))
        print("Accuracy on test set: ",clf.score(X_test, y_test))
        ROC_PRC_matrix(clf, y_test, X_test)
        confusion_matrix(clf, y_test, X_test)
# Out:
# Logistic Regression
# --------------------
# Accuracy on training set:  0.40994609164420487
# Accuracy on test set:  0.4180681328158689
#
# Decision Tree
# --------------------
# Accuracy on training set:  0.40358490566037736
# Accuracy on test set:  0.41343251401466147
#
# Random Forest
# --------------------
# Accuracy on training set:  0.4287061994609164
# Accuracy on test set:  0.4282018111254851

# %%
result_in = le.inverse_transform(prediction_in).tolist()
result_out = le.inverse_transform(prediction_out).tolist()
result = result_in + result_out
dataset_sincambios['Predictions'] = result

# %%
dataset_sincambios.loc[(dataset_sincambios['season'] == '2010-2011') & (dataset_sincambios['division'] == 1) & (dataset_sincambios['matchday'] == 3)]
# Out:
#           season  division  matchday             team      Away_team    W  \
# 38698  2010-2011         1         3         Espanyol     UD Almería  1.0
# 38702  2010-2011         1         3     RCD Mallorca     CA Osasuna  0.0
# 38705  2010-2011         1         3   Sporting Gijón       Athletic  1.0
# 38699  2010-2011         1         3      Real Madrid  Real Sociedad  1.0
# 38703  2010-2011         1         3         Valencia    Hércules CF  2.0
# 38700  2010-2011         1         3    Real Zaragoza         Racing  0.0
# 38704  2010-2011         1         3       Villarreal        Levante  1.0
# 38696  2010-2011         1         3  Atlético Madrid      Barcelona  2.0
# 38701  2010-2011         1         3        Málaga CF     Sevilla FC  1.0
# 38697  2010-2011         1         3   Dep. La Coruña         Getafe  0.0
#
#          L    T result  rank  GD_home  GD_away Predictions
# 38698  1.0  0.0      W  13.0     -2.0      2.0           W
# 38702  1.0  1.0      W  18.0     -2.0      2.0           L
# 38705  1.0  0.0      T   9.0     -2.0      2.0           L
# 38699  0.0  1.0      W   3.0      1.0     -1.0           L
# 38703  0.0  0.0      W   2.0      3.0     -3.0           L
# 38700  1.0  1.0      L  17.0     -2.0      2.0           W
# 38704  1.0  0.0      W   6.0      3.0     -3.0           L
# 38696  0.0  0.0      L   1.0      5.0     -5.0           L
# 38701  1.0  0.0      L   8.0      0.0      0.0           L
# 38697  0.0  2.0      T  15.0      0.0      0.0           W
