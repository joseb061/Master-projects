# %%
import pandas as pd
import seaborn  
import matplotlib.pyplot as plt

# %% [markdown]
# Heuristica usada:
#
# float heuristic(node *Graph, unsigned vertex, unsigned goal) {
#
#     return cos_weight(Graph[goal].latitude, Graph[goal].longitude, Graph[vertex].latitude, Graph[vertex].longitude);
#
# }
#
# (La más simple, una línea recta)

# %%
lambda_data1 = pd.read_csv('lambda_resuts.txt',sep=";",header=None)
lambda_data1.columns = ["Lambda","Distance","Number of iterations","Execution time A*"]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7392/540751466.py in <module>
# ----> 1 lambda_data1 = pd.read_csv('lambda_resuts.txt',sep=";",header=None)
#       2 lambda_data1.columns = ["Lambda","Distance","Number of iterations","Execution time A*"]
#
# c:\users\jorge\appdata\local\programs\python\python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\users\jorge\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# c:\users\jorge\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# c:\users\jorge\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# c:\users\jorge\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# c:\users\jorge\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# c:\users\jorge\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# c:\users\jorge\appdata\local\programs\python\python39\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'lambda_resuts.txt'

# %%
# Selecting lambda that minimizes execution time
data = lambda_data1[["Lambda","Execution time A*"]].loc[lambda_data1['Distance']==958.765625]
data[data['Execution time A*'] == data['Execution time A*'].min()]
# Out:
#     Lambda  Execution time A*
# 76   1.104              4.656

# %%
lambda_data1.loc[lambda_data1["Lambda"]==1]
lambda_data1.loc[lambda_data1["Lambda"]==1.12]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7392/3511193835.py in <module>
# ----> 1 lambda_data1.loc[lambda_data1["Lambda"]==1]
#       2 lambda_data1.loc[lambda_data1["Lambda"]==1.12]
#
# NameError: name 'lambda_data1' is not defined

# %%
graph1 = seaborn.relplot(
    data=lambda_data1, kind="line",
    x="Lambda", y="Number of iterations",
)
graph1.fig.suptitle('Number of iterations by lambda value')
plt.savefig("Iterations.png")

# %%
graph2 = seaborn.relplot(
    data=lambda_data1, kind="line",
    x="Lambda", y="Distance",
)
graph2.fig.suptitle('Distance by lambda value')
plt.savefig("Distance.png")

# %%
graph3 = seaborn.relplot(
    data=lambda_data1, kind="line",
    x="Lambda", y="Execution time A*",
)
graph3.fig.suptitle('Execution time by lambda value')
plt.savefig("Execution_time.png")

# %%
import matplotlib.pyplot as plt
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(lambda_data1['Lambda'], lambda_data1['Execution time A*'], color="red")
# set x-axis label
ax.set_xlabel("Lambda",fontsize=14)
# set y-axis label
ax.set_ylabel("Execution time A*",color="red",fontsize=14)
# twin object for two different y-axis on the sample plot
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(lambda_data1['Lambda'], lambda_data1['Distance'],color="blue")
ax2.set_ylabel("Distance",color="blue",fontsize=14)
#plt.show()
plt.savefig("Exe_vs_distance.png")
