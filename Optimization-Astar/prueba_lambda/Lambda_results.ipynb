# %%
import pandas as pd
import seaborn

# %% [markdown]
# Heuristica usada:
#
# float heuristic(node *Graph, unsigned vertex, unsigned goal) {
#
#     return cos_weight(Graph[goal].latitude, Graph[goal].longitude, Graph[vertex].latitude, Graph[vertex].longitude);
#
# }
#
# (La más simple, una línea recta)

# %%
lambda_data1 = pd.read_csv('lambda_resuts_h1.txt',sep=";",header=None)
lambda_data1.columns = ["Lambda","Distance","Number of iterations","Execution time A*"]

# %%
seaborn.relplot(
    data=lambda_data1, kind="line",
    x="Lambda", y="Number of iterations",
)

# %%
seaborn.relplot(
    data=lambda_data1, kind="line",
    x="Lambda", y="Distance",
)

# %%
seaborn.relplot(
    data=lambda_data1, kind="line",
    x="Lambda", y="Execution time A*",
)

# %%
import matplotlib.pyplot as plt
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(lambda_data1['Lambda'], lambda_data1['Execution time A*'], color="red")
# set x-axis label
ax.set_xlabel("Lambda",fontsize=14)
# set y-axis label
ax.set_ylabel("Execution time A*",color="red",fontsize=14)
# twin object for two different y-axis on the sample plot
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(lambda_data1['Lambda'], lambda_data1['Distance'],color="blue")
ax2.set_ylabel("Distance",color="blue",fontsize=14)
plt.show()

# %% [markdown]
# Heuristic used:
#
# float heuristic(node *Graph, unsigned vertex, unsigned goal) { // Returns the minimum distance of all the vertexes.
#
#     register unsigned short i;
#     float initial_weigth, seg_weight;
#     unsigned suc_node;
#
#      if (vertex == goal)
#          return 0.0;
#
#      initial_weigth = cos_weight(Graph[goal].latitude, Graph[goal].longitude, Graph[Graph[vertex].segment[0]].latitude, Graph[Graph[vertex].segment[0]].longitude);
#      float minw = initial_weigth;
#
#      for (i = 1; i < Graph[vertex].numbersegments; i++){
#          suc_node = Graph[vertex].segment[i];
#          seg_weight = cos_weight(Graph[goal].latitude, Graph[goal].longitude, Graph[suc_node].latitude, Graph[suc_node].longitude);
#          if (seg_weight < minw)
#              minw = seg_weight;
#      }
#      return minw;
#  }

# %%
lambda_data2 = pd.read_csv('lambda_resuts_h2.txt',sep=";",header=None)
lambda_data2.columns = ["Lambda","Distance","Number of iterations","Execution time A*"]

# %%
seaborn.relplot(
    data=lambda_data2, kind="line",
    x="Lambda", y="Number of iterations",
)

# %%
seaborn.relplot(
    data=lambda_data2, kind="line",
    x="Lambda", y="Distance",
)

# %%
seaborn.relplot(
    data=lambda_data2, kind="line",
    x="Lambda", y="Execution time A*",
)

# %%
import matplotlib.pyplot as plt
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(lambda_data2['Lambda'], lambda_data2['Execution time A*'], color="red")
# set x-axis label
ax.set_xlabel("Lambda",fontsize=14)
# set y-axis label
ax.set_ylabel("Execution time A*",color="red",fontsize=14)
# twin object for two different y-axis on the sample plot
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(lambda_data2['Lambda'], lambda_data2['Distance'],color="blue")
ax2.set_ylabel("Distance",color="blue",fontsize=14)
plt.show()
