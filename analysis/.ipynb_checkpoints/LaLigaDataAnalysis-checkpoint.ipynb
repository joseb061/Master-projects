# %%
import sqlite3

# %%
import pandas as pd

# %%
with sqlite3.connect("../laliga.sqlite") as conn:
    df = pd.read_sql("SELECT * FROM Matches", con = conn)

# %%
df
# Out:
#           season  division  matchday     date  time        home_team  \
# 0      1928-1929         1         1  2/10/29  None      Arenas Club
# 1      1928-1929         1         1  2/10/29  None         Espanyol
# 2      1928-1929         1         1  2/10/29  None      Real Madrid
# 3      1928-1929         1         1  2/10/29  None         Donostia
# 4      1928-1929         1         1  2/12/29  None           Racing
# ...          ...       ...       ...      ...   ...              ...
# 49015  2021-2022         2        42  5/29/22  None      Real Oviedo
# 49016  2021-2022         2        42  5/29/22  None  Real Sociedad B
# 49017  2021-2022         2        42  5/29/22  None   Sporting Gijón
# 49018  2021-2022         2        42  5/29/22  None      CD Tenerife
# 49019  2021-2022         2        42  5/29/22  None  Real Valladolid
#
#              away_team score
# 0      Athletic Madrid   2:3
# 1           Real Unión   3:2
# 2            Catalunya   5:0
# 3             Athletic   1:1
# 4            Barcelona   0:2
# ...                ...   ...
# 49015         UD Ibiza  None
# 49016    Real Zaragoza  None
# 49017    UD Las Palmas  None
# 49018     FC Cartagena  None
# 49019        SD Huesca  None
#
# [49020 rows x 8 columns]

# %%
def parse_score(score_as_string):
        if score_as_string is None: 
            return None
        home_goals, away_goals = score_as_string.split(":")
        home_goals = int(home_goals)
        away_goals = int(away_goals)
        if home_goals > away_goals: 
            return "1"
        if away_goals > home_goals: 
            return "2" 
        else: 
            return "X"

# %%
df['result'] = df['score'].apply(parse_score)

# %%
df["result"].value_counts().plot(kind="pie")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-e39807a6d0d4> in <module>
# ----> 1 df["result"].value_counts().plot(kind="pie")
#
# ~/Master/Research_Innnovation/final_proyect/Research-Innovation/.venv-FP/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     867
#     868     def __call__(self, *args, **kwargs):
# --> 869         plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     870
#     871         x, y, kind, kwargs = self._get_call_args(
#
# ~/Master/Research_Innnovation/final_proyect/Research-Innovation/.venv-FP/lib/python3.6/site-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1781                 "matplotlib is required for plotting when the "
#    1782                 'default backend "matplotlib" is selected.'
# -> 1783             ) from None
#    1784
#    1785         _backends["matplotlib"] = module
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.

# %%
df
# Out:
#           season  division  matchday     date  time        home_team  \
# 0      1928-1929         1         1  2/10/29  None      Arenas Club
# 1      1928-1929         1         1  2/10/29  None         Espanyol
# 2      1928-1929         1         1  2/10/29  None      Real Madrid
# 3      1928-1929         1         1  2/10/29  None         Donostia
# 4      1928-1929         1         1  2/12/29  None           Racing
# ...          ...       ...       ...      ...   ...              ...
# 49015  2021-2022         2        42  5/29/22  None      Real Oviedo
# 49016  2021-2022         2        42  5/29/22  None  Real Sociedad B
# 49017  2021-2022         2        42  5/29/22  None   Sporting Gijón
# 49018  2021-2022         2        42  5/29/22  None      CD Tenerife
# 49019  2021-2022         2        42  5/29/22  None  Real Valladolid
#
#              away_team score result
# 0      Athletic Madrid   2:3      2
# 1           Real Unión   3:2      1
# 2            Catalunya   5:0      1
# 3             Athletic   1:1      X
# 4            Barcelona   0:2      2
# ...                ...   ...    ...
# 49015         UD Ibiza  None   None
# 49016    Real Zaragoza  None   None
# 49017    UD Las Palmas  None   None
# 49018     FC Cartagena  None   None
# 49019        SD Huesca  None   None
#
# [49020 rows x 9 columns]
